# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshugoyal77/DAV_LAB/blob/main/DAV_Experiment_7_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aim: Perform the steps involved in Text Analytics in Python & R

# %%
with open('text.txt', 'r') as file:
    text = file.read()

# %%
len(text.split(" "))
# Out:
# 169893

# %%
for line in text[:1000]:
    print(line, end="")
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag, ne_chunk

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# **Tokenization**

# %%
sentences = sent_tokenize(text)
print("Sentences:", sentences[1:10])
# Out:
# Sentences: ['All:\nSpeak, speak.', 'First Citizen:\nYou are all resolved rather to die than to famish?', 'All:\nResolved.', 'resolved.', 'First Citizen:\nFirst, you know Caius Marcius is chief enemy to the people.', "All:\nWe know't, we know't.", "First Citizen:\nLet us kill him, and we'll have corn at our own price.", "Is't a verdict?", "All:\nNo more talking on't; let it be done: away, away!"]

# %%
words = word_tokenize(text)
print("Words:", words[1:1000])
# Out:
# Words: ['Citizen', ':', 'Before', 'we', 'proceed', 'any', 'further', ',', 'hear', 'me', 'speak', '.', 'All', ':', 'Speak', ',', 'speak', '.', 'First', 'Citizen', ':', 'You', 'are', 'all', 'resolved', 'rather', 'to', 'die', 'than', 'to', 'famish', '?', 'All', ':', 'Resolved', '.', 'resolved', '.', 'First', 'Citizen', ':', 'First', ',', 'you', 'know', 'Caius', 'Marcius', 'is', 'chief', 'enemy', 'to', 'the', 'people', '.', 'All', ':', 'We', "know't", ',', 'we', "know't", '.', 'First', 'Citizen', ':', 'Let', 'us', 'kill', 'him', ',', 'and', 'we', "'ll", 'have', 'corn', 'at', 'our', 'own', 'price', '.', "Is't", 'a', 'verdict', '?', 'All', ':', 'No', 'more', 'talking', 'o', "n't", ';', 'let', 'it', 'be', 'done', ':', 'away', ',', 'away', '!', 'Second', 'Citizen', ':', 'One', 'word', ',', 'good', 'citizens', '.', 'First', 'Citizen', ':', 'We', 'are', 'accounted', 'poor', 'citizens', ',', 'the', 'patricians', 'good', '.', 'What', 'authority', 'surfeits', 'on', 'would', 'relieve', 'us', ':', 'if', 'they', 'would', 'yield', 'us', 'but', 'the', 'superfluity', ',', 'while', 'it', 'were', 'wholesome', ',', 'we', 'might', 'guess', 'they', 'relieved', 'us', 'humanely', ';', 'but', 'they', 'think', 'we', 'are', 'too', 'dear', ':', 'the', 'leanness', 'that', 'afflicts', 'us', ',', 'the', 'object', 'of', 'our', 'misery', ',', 'is', 'as', 'an', 'inventory', 'to', 'particularise', 'their', 'abundance', ';', 'our', 'sufferance', 'is', 'a', 'gain', 'to', 'them', 'Let', 'us', 'revenge', 'this', 'with', 'our', 'pikes', ',', 'ere', 'we', 'become', 'rakes', ':', 'for', 'the', 'gods', 'know', 'I', 'speak', 'this', 'in', 'hunger', 'for', 'bread', ',', 'not', 'in', 'thirst', 'for', 'revenge', '.', 'Second', 'Citizen', ':', 'Would', 'you', 'proceed', 'especially', 'against', 'Caius', 'Marcius', '?', 'All', ':', 'Against', 'him', 'first', ':', 'he', "'s", 'a', 'very', 'dog', 'to', 'the', 'commonalty', '.', 'Second', 'Citizen', ':', 'Consider', 'you', 'what', 'services', 'he', 'has', 'done', 'for', 'his', 'country', '?', 'First', 'Citizen', ':', 'Very', 'well', ';', 'and', 'could', 'be', 'content', 'to', 'give', 'him', 'good', 'report', 'fort', ',', 'but', 'that', 'he', 'pays', 'himself', 'with', 'being', 'proud', '.', 'Second', 'Citizen', ':', 'Nay', ',', 'but', 'speak', 'not', 'maliciously', '.', 'First', 'Citizen', ':', 'I', 'say', 'unto', 'you', ',', 'what', 'he', 'hath', 'done', 'famously', ',', 'he', 'did', 'it', 'to', 'that', 'end', ':', 'though', 'soft-conscienced', 'men', 'can', 'be', 'content', 'to', 'say', 'it', 'was', 'for', 'his', 'country', 'he', 'did', 'it', 'to', 'please', 'his', 'mother', 'and', 'to', 'be', 'partly', 'proud', ';', 'which', 'he', 'is', ',', 'even', 'till', 'the', 'altitude', 'of', 'his', 'virtue', '.', 'Second', 'Citizen', ':', 'What', 'he', 'can', 'not', 'help', 'in', 'his', 'nature', ',', 'you', 'account', 'a', 'vice', 'in', 'him', '.', 'You', 'must', 'in', 'no', 'way', 'say', 'he', 'is', 'covetous', '.', 'First', 'Citizen', ':', 'If', 'I', 'must', 'not', ',', 'I', 'need', 'not', 'be', 'barren', 'of', 'accusations', ';', 'he', 'hath', 'faults', ',', 'with', 'surplus', ',', 'to', 'tire', 'in', 'repetition', '.', 'What', 'shouts', 'are', 'these', '?', 'The', 'other', 'side', 'o', "'", 'the', 'city', 'is', 'risen', ':', 'why', 'stay', 'we', 'prating', 'here', '?', 'to', 'the', 'Capitol', '!', 'All', ':', 'Come', ',', 'come', '.', 'First', 'Citizen', ':', 'Soft', '!', 'who', 'comes', 'here', '?', 'Second', 'Citizen', ':', 'Worthy', 'Menenius', 'Agrippa', ';', 'one', 'that', 'hath', 'always', 'loved', 'the', 'people', '.', 'First', 'Citizen', ':', 'He', "'s", 'one', 'honest', 'enough', ':', 'would', 'all', 'the', 'rest', 'were', 'so', '!', 'MENENIUS', ':', 'What', 'work', "'s", ',', 'my', 'countrymen', ',', 'in', 'hand', '?', 'where', 'go', 'you', 'With', 'bats', 'and', 'clubs', '?', 'The', 'matter', '?', 'speak', ',', 'I', 'pray', 'you', '.', 'First', 'Citizen', ':', 'Our', 'business', 'is', 'not', 'unknown', 'to', 'the', 'sena ...

# %% [markdown]
# **Frequency Distribution**

# %%
fdist = FreqDist(words)
print("Frequency Distribution:", fdist)
print("\nMost common:", fdist.most_common(10))
# Out:
# Frequency Distribution: <FreqDist with 14310 samples and 254509 outcomes>
#
# Most common: [(',', 19846), (':', 10316), ('.', 7858), ('the', 5441), ('I', 5013), ('to', 3974), ('and', 3761), (';', 3628), ('of', 3314), ('you', 2849)]

# %% [markdown]
# **Removing Stop Words**

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

print("Filtered Words (Stopwords & Punctuations removed):", filtered_words[1:1000])
# Out:
# Filtered Words (Stopwords & Punctuations removed): ['citizen', 'proceed', 'hear', 'speak', 'speak', 'speak', 'first', 'citizen', 'resolved', 'rather', 'die', 'famish', 'resolved', 'resolved', 'first', 'citizen', 'first', 'know', 'caius', 'marcius', 'chief', 'enemy', 'people', 'first', 'citizen', 'let', 'us', 'kill', 'corn', 'price', 'verdict', 'talking', 'let', 'done', 'away', 'away', 'second', 'citizen', 'one', 'word', 'good', 'citizens', 'first', 'citizen', 'accounted', 'poor', 'citizens', 'patricians', 'good', 'authority', 'surfeits', 'would', 'relieve', 'us', 'would', 'yield', 'us', 'superfluity', 'wholesome', 'might', 'guess', 'relieved', 'us', 'humanely', 'think', 'dear', 'leanness', 'afflicts', 'us', 'object', 'misery', 'inventory', 'particularise', 'abundance', 'sufferance', 'gain', 'let', 'us', 'revenge', 'pikes', 'ere', 'become', 'rakes', 'gods', 'know', 'speak', 'hunger', 'bread', 'thirst', 'revenge', 'second', 'citizen', 'would', 'proceed', 'especially', 'caius', 'marcius', 'first', 'dog', 'commonalty', 'second', 'citizen', 'consider', 'services', 'done', 'country', 'first', 'citizen', 'well', 'could', 'content', 'give', 'good', 'report', 'fort', 'pays', 'proud', 'second', 'citizen', 'nay', 'speak', 'maliciously', 'first', 'citizen', 'say', 'unto', 'hath', 'done', 'famously', 'end', 'though', 'men', 'content', 'say', 'country', 'please', 'mother', 'partly', 'proud', 'even', 'till', 'altitude', 'virtue', 'second', 'citizen', 'help', 'nature', 'account', 'vice', 'must', 'way', 'say', 'covetous', 'first', 'citizen', 'must', 'need', 'barren', 'accusations', 'hath', 'faults', 'surplus', 'tire', 'repetition', 'shouts', 'side', 'city', 'risen', 'stay', 'prating', 'capitol', 'come', 'come', 'first', 'citizen', 'soft', 'comes', 'second', 'citizen', 'worthy', 'menenius', 'agrippa', 'one', 'hath', 'always', 'loved', 'people', 'first', 'citizen', 'one', 'honest', 'enough', 'would', 'rest', 'menenius', 'work', 'countrymen', 'hand', 'go', 'bats', 'clubs', 'matter', 'speak', 'pray', 'first', 'citizen', 'business', 'unknown', 'senate', 'inkling', 'fortnight', 'intend', 'show', 'deeds', 'say', 'poor', 'suitors', 'strong', 'breaths', 'shall', 'know', 'strong', 'arms', 'menenius', 'masters', 'good', 'friends', 'mine', 'honest', 'neighbours', 'undo', 'first', 'citizen', 'sir', 'undone', 'already', 'menenius', 'tell', 'friends', 'charitable', 'care', 'patricians', 'wants', 'suffering', 'dearth', 'may', 'well', 'strike', 'heaven', 'staves', 'lift', 'roman', 'state', 'whose', 'course', 'way', 'takes', 'cracking', 'ten', 'thousand', 'curbs', 'strong', 'link', 'asunder', 'ever', 'appear', 'impediment', 'dearth', 'gods', 'patricians', 'make', 'knees', 'arms', 'must', 'help', 'alack', 'transported', 'calamity', 'thither', 'attends', 'slander', 'helms', 'state', 'care', 'like', 'fathers', 'curse', 'enemies', 'first', 'citizen', 'care', 'us', 'true', 'indeed', 'cared', 'us', 'yet', 'suffer', 'us', 'famish', 'crammed', 'grain', 'make', 'edicts', 'usury', 'support', 'usurers', 'repeal', 'daily', 'wholesome', 'act', 'established', 'rich', 'provide', 'piercing', 'statutes', 'daily', 'chain', 'restrain', 'poor', 'wars', 'eat', 'us', 'love', 'bear', 'us', 'menenius', 'either', 'must', 'confess', 'wondrous', 'malicious', 'accused', 'folly', 'shall', 'tell', 'pretty', 'tale', 'may', 'heard', 'since', 'serves', 'purpose', 'venture', 'stale', 'little', 'first', 'citizen', 'well', 'hear', 'sir', 'yet', 'must', 'think', 'fob', 'disgrace', 'tale', 'please', 'deliver', 'menenius', 'time', 'body', 'members', 'rebell', 'belly', 'thus', 'accused', 'like', 'gulf', 'remain', 'midst', 'body', 'idle', 'unactive', 'still', 'cupboarding', 'viand', 'never', 'bearing', 'like', 'labour', 'rest', 'instruments', 'see', 'hear', 'devise', 'instruct', 'walk', 'feel', 'mutually', 'participate', 'minister', 'unto', 'appetite', 'affection', 'common', 'whole', 'body', 'belly', 'answer', 'first', 'citizen', 'well', 'sir', 'answer', 'made', 'belly', 'menenius', 'sir', 'shall', 't ...

# %%
fdist = FreqDist(filtered_words)
print("Frequency Distribution:", fdist)
print("\nMost common:", fdist.most_common(10))
# Out:
# Frequency Distribution: <FreqDist with 11008 samples and 103492 outcomes>
#
# Most common: [('thou', 1403), ('thy', 1059), ('king', 923), ('shall', 842), ('thee', 762), ('lord', 709), ('good', 662), ('come', 622), ('sir', 595), ('would', 534)]

# %% [markdown]
# **Stemming**

# %%
porter_stemmer = PorterStemmer()
stemmed_words = [porter_stemmer.stem(word) for word in filtered_words]

print("Stemmed Words:", stemmed_words[1:1000])
# Out:
# Stemmed Words: ['citizen', 'proceed', 'hear', 'speak', 'speak', 'speak', 'first', 'citizen', 'resolv', 'rather', 'die', 'famish', 'resolv', 'resolv', 'first', 'citizen', 'first', 'know', 'caiu', 'marciu', 'chief', 'enemi', 'peopl', 'first', 'citizen', 'let', 'us', 'kill', 'corn', 'price', 'verdict', 'talk', 'let', 'done', 'away', 'away', 'second', 'citizen', 'one', 'word', 'good', 'citizen', 'first', 'citizen', 'account', 'poor', 'citizen', 'patrician', 'good', 'author', 'surfeit', 'would', 'reliev', 'us', 'would', 'yield', 'us', 'superflu', 'wholesom', 'might', 'guess', 'reliev', 'us', 'human', 'think', 'dear', 'lean', 'afflict', 'us', 'object', 'miseri', 'inventori', 'particularis', 'abund', 'suffer', 'gain', 'let', 'us', 'reveng', 'pike', 'ere', 'becom', 'rake', 'god', 'know', 'speak', 'hunger', 'bread', 'thirst', 'reveng', 'second', 'citizen', 'would', 'proceed', 'especi', 'caiu', 'marciu', 'first', 'dog', 'commonalti', 'second', 'citizen', 'consid', 'servic', 'done', 'countri', 'first', 'citizen', 'well', 'could', 'content', 'give', 'good', 'report', 'fort', 'pay', 'proud', 'second', 'citizen', 'nay', 'speak', 'malici', 'first', 'citizen', 'say', 'unto', 'hath', 'done', 'famous', 'end', 'though', 'men', 'content', 'say', 'countri', 'pleas', 'mother', 'partli', 'proud', 'even', 'till', 'altitud', 'virtu', 'second', 'citizen', 'help', 'natur', 'account', 'vice', 'must', 'way', 'say', 'covet', 'first', 'citizen', 'must', 'need', 'barren', 'accus', 'hath', 'fault', 'surplu', 'tire', 'repetit', 'shout', 'side', 'citi', 'risen', 'stay', 'prate', 'capitol', 'come', 'come', 'first', 'citizen', 'soft', 'come', 'second', 'citizen', 'worthi', 'meneniu', 'agrippa', 'one', 'hath', 'alway', 'love', 'peopl', 'first', 'citizen', 'one', 'honest', 'enough', 'would', 'rest', 'meneniu', 'work', 'countrymen', 'hand', 'go', 'bat', 'club', 'matter', 'speak', 'pray', 'first', 'citizen', 'busi', 'unknown', 'senat', 'inkl', 'fortnight', 'intend', 'show', 'deed', 'say', 'poor', 'suitor', 'strong', 'breath', 'shall', 'know', 'strong', 'arm', 'meneniu', 'master', 'good', 'friend', 'mine', 'honest', 'neighbour', 'undo', 'first', 'citizen', 'sir', 'undon', 'alreadi', 'meneniu', 'tell', 'friend', 'charit', 'care', 'patrician', 'want', 'suffer', 'dearth', 'may', 'well', 'strike', 'heaven', 'stave', 'lift', 'roman', 'state', 'whose', 'cours', 'way', 'take', 'crack', 'ten', 'thousand', 'curb', 'strong', 'link', 'asund', 'ever', 'appear', 'impedi', 'dearth', 'god', 'patrician', 'make', 'knee', 'arm', 'must', 'help', 'alack', 'transport', 'calam', 'thither', 'attend', 'slander', 'helm', 'state', 'care', 'like', 'father', 'curs', 'enemi', 'first', 'citizen', 'care', 'us', 'true', 'inde', 'care', 'us', 'yet', 'suffer', 'us', 'famish', 'cram', 'grain', 'make', 'edict', 'usuri', 'support', 'usur', 'repeal', 'daili', 'wholesom', 'act', 'establish', 'rich', 'provid', 'pierc', 'statut', 'daili', 'chain', 'restrain', 'poor', 'war', 'eat', 'us', 'love', 'bear', 'us', 'meneniu', 'either', 'must', 'confess', 'wondrou', 'malici', 'accus', 'folli', 'shall', 'tell', 'pretti', 'tale', 'may', 'heard', 'sinc', 'serv', 'purpos', 'ventur', 'stale', 'littl', 'first', 'citizen', 'well', 'hear', 'sir', 'yet', 'must', 'think', 'fob', 'disgrac', 'tale', 'pleas', 'deliv', 'meneniu', 'time', 'bodi', 'member', 'rebel', 'belli', 'thu', 'accus', 'like', 'gulf', 'remain', 'midst', 'bodi', 'idl', 'unact', 'still', 'cupboard', 'viand', 'never', 'bear', 'like', 'labour', 'rest', 'instrument', 'see', 'hear', 'devis', 'instruct', 'walk', 'feel', 'mutual', 'particip', 'minist', 'unto', 'appetit', 'affect', 'common', 'whole', 'bodi', 'belli', 'answer', 'first', 'citizen', 'well', 'sir', 'answer', 'made', 'belli', 'meneniu', 'sir', 'shall', 'tell', 'kind', 'smile', 'came', 'lung', 'even', 'thu', 'look', 'may', 'make', 'belli', 'smile', 'well', 'speak', 'tauntingli', 'repli', 'discont', 'member', 'mutin', 'part', 'envi', 'receipt', 'even', 'fitli', 'malign', 'senat', 'first', 'citizen', 'belli',  ...

# %% [markdown]
# **Lemmatization**

# %%
lemmatizer = WordNetLemmatizer()
lemma = [lemmatizer.lemmatize(word) for word in filtered_words]

print("Lemmatized Words:", lemma[1:1000])
# Out:
# Lemmatized Words: ['citizen', 'proceed', 'hear', 'speak', 'speak', 'speak', 'first', 'citizen', 'resolved', 'rather', 'die', 'famish', 'resolved', 'resolved', 'first', 'citizen', 'first', 'know', 'caius', 'marcius', 'chief', 'enemy', 'people', 'first', 'citizen', 'let', 'u', 'kill', 'corn', 'price', 'verdict', 'talking', 'let', 'done', 'away', 'away', 'second', 'citizen', 'one', 'word', 'good', 'citizen', 'first', 'citizen', 'accounted', 'poor', 'citizen', 'patrician', 'good', 'authority', 'surfeit', 'would', 'relieve', 'u', 'would', 'yield', 'u', 'superfluity', 'wholesome', 'might', 'guess', 'relieved', 'u', 'humanely', 'think', 'dear', 'leanness', 'afflicts', 'u', 'object', 'misery', 'inventory', 'particularise', 'abundance', 'sufferance', 'gain', 'let', 'u', 'revenge', 'pike', 'ere', 'become', 'rake', 'god', 'know', 'speak', 'hunger', 'bread', 'thirst', 'revenge', 'second', 'citizen', 'would', 'proceed', 'especially', 'caius', 'marcius', 'first', 'dog', 'commonalty', 'second', 'citizen', 'consider', 'service', 'done', 'country', 'first', 'citizen', 'well', 'could', 'content', 'give', 'good', 'report', 'fort', 'pay', 'proud', 'second', 'citizen', 'nay', 'speak', 'maliciously', 'first', 'citizen', 'say', 'unto', 'hath', 'done', 'famously', 'end', 'though', 'men', 'content', 'say', 'country', 'please', 'mother', 'partly', 'proud', 'even', 'till', 'altitude', 'virtue', 'second', 'citizen', 'help', 'nature', 'account', 'vice', 'must', 'way', 'say', 'covetous', 'first', 'citizen', 'must', 'need', 'barren', 'accusation', 'hath', 'fault', 'surplus', 'tire', 'repetition', 'shout', 'side', 'city', 'risen', 'stay', 'prating', 'capitol', 'come', 'come', 'first', 'citizen', 'soft', 'come', 'second', 'citizen', 'worthy', 'menenius', 'agrippa', 'one', 'hath', 'always', 'loved', 'people', 'first', 'citizen', 'one', 'honest', 'enough', 'would', 'rest', 'menenius', 'work', 'countryman', 'hand', 'go', 'bat', 'club', 'matter', 'speak', 'pray', 'first', 'citizen', 'business', 'unknown', 'senate', 'inkling', 'fortnight', 'intend', 'show', 'deed', 'say', 'poor', 'suitor', 'strong', 'breath', 'shall', 'know', 'strong', 'arm', 'menenius', 'master', 'good', 'friend', 'mine', 'honest', 'neighbour', 'undo', 'first', 'citizen', 'sir', 'undone', 'already', 'menenius', 'tell', 'friend', 'charitable', 'care', 'patrician', 'want', 'suffering', 'dearth', 'may', 'well', 'strike', 'heaven', 'stave', 'lift', 'roman', 'state', 'whose', 'course', 'way', 'take', 'cracking', 'ten', 'thousand', 'curb', 'strong', 'link', 'asunder', 'ever', 'appear', 'impediment', 'dearth', 'god', 'patrician', 'make', 'knee', 'arm', 'must', 'help', 'alack', 'transported', 'calamity', 'thither', 'attends', 'slander', 'helm', 'state', 'care', 'like', 'father', 'curse', 'enemy', 'first', 'citizen', 'care', 'u', 'true', 'indeed', 'cared', 'u', 'yet', 'suffer', 'u', 'famish', 'crammed', 'grain', 'make', 'edict', 'usury', 'support', 'usurer', 'repeal', 'daily', 'wholesome', 'act', 'established', 'rich', 'provide', 'piercing', 'statute', 'daily', 'chain', 'restrain', 'poor', 'war', 'eat', 'u', 'love', 'bear', 'u', 'menenius', 'either', 'must', 'confess', 'wondrous', 'malicious', 'accused', 'folly', 'shall', 'tell', 'pretty', 'tale', 'may', 'heard', 'since', 'serf', 'purpose', 'venture', 'stale', 'little', 'first', 'citizen', 'well', 'hear', 'sir', 'yet', 'must', 'think', 'fob', 'disgrace', 'tale', 'please', 'deliver', 'menenius', 'time', 'body', 'member', 'rebell', 'belly', 'thus', 'accused', 'like', 'gulf', 'remain', 'midst', 'body', 'idle', 'unactive', 'still', 'cupboarding', 'viand', 'never', 'bearing', 'like', 'labour', 'rest', 'instrument', 'see', 'hear', 'devise', 'instruct', 'walk', 'feel', 'mutually', 'participate', 'minister', 'unto', 'appetite', 'affection', 'common', 'whole', 'body', 'belly', 'answer', 'first', 'citizen', 'well', 'sir', 'answer', 'made', 'belly', 'menenius', 'sir', 'shall', 'tell', 'kind', 'smile', 'came', 'lung', 'even', 'thus', 'look', 'may', 'make', 'belly', ' ...

# %% [markdown]
# **Parts Of Speech**

# %%
pos_tags = pos_tag(filtered_words)

print("Part of Speech Tagging:", pos_tags[1:100])
# Out:
# Part of Speech Tagging: [('citizen', 'JJ'), ('proceed', 'NN'), ('hear', 'VBP'), ('speak', 'JJ'), ('speak', 'NN'), ('speak', 'NN'), ('first', 'RB'), ('citizen', 'VBZ'), ('resolved', 'VBN'), ('rather', 'RB'), ('die', 'JJ'), ('famish', 'JJ'), ('resolved', 'VBD'), ('resolved', 'VBN'), ('first', 'RB'), ('citizen', 'JJ'), ('first', 'RB'), ('know', 'VBP'), ('caius', 'JJ'), ('marcius', 'NN'), ('chief', 'JJ'), ('enemy', 'NN'), ('people', 'NNS'), ('first', 'RB'), ('citizen', 'VBP'), ('let', 'VB'), ('us', 'PRP'), ('kill', 'VB'), ('corn', 'NN'), ('price', 'NN'), ('verdict', 'NN'), ('talking', 'VBG'), ('let', 'VB'), ('done', 'VBN'), ('away', 'RB'), ('away', 'RB'), ('second', 'JJ'), ('citizen', 'JJ'), ('one', 'CD'), ('word', 'NN'), ('good', 'NN'), ('citizens', 'NNS'), ('first', 'JJ'), ('citizen', 'RB'), ('accounted', 'VBD'), ('poor', 'JJ'), ('citizens', 'NNS'), ('patricians', 'NNS'), ('good', 'JJ'), ('authority', 'NN'), ('surfeits', 'NNS'), ('would', 'MD'), ('relieve', 'VB'), ('us', 'PRP'), ('would', 'MD'), ('yield', 'VB'), ('us', 'PRP'), ('superfluity', 'JJ'), ('wholesome', 'NN'), ('might', 'MD'), ('guess', 'VB'), ('relieved', 'VBD'), ('us', 'PRP'), ('humanely', 'RB'), ('think', 'VBP'), ('dear', 'JJ'), ('leanness', 'NN'), ('afflicts', 'VBZ'), ('us', 'PRP'), ('object', 'JJ'), ('misery', 'NN'), ('inventory', 'NN'), ('particularise', 'NN'), ('abundance', 'NN'), ('sufferance', 'NN'), ('gain', 'NN'), ('let', 'VBD'), ('us', 'PRP'), ('revenge', 'VB'), ('pikes', 'NNS'), ('ere', 'RB'), ('become', 'VBP'), ('rakes', 'JJ'), ('gods', 'NNS'), ('know', 'VBP'), ('speak', 'JJ'), ('hunger', 'NN'), ('bread', 'NN'), ('thirst', 'JJ'), ('revenge', 'NN'), ('second', 'JJ'), ('citizen', 'NN'), ('would', 'MD'), ('proceed', 'VB'), ('especially', 'RB'), ('caius', 'JJ'), ('marcius', 'NNS'), ('first', 'RB'), ('dog', 'VBP')]

# %% [markdown]
# **Named Entity Regognition**

# %%
ne_tree = ne_chunk(pos_tags)

print("Named Entity Recognition:", ne_tree)
# Out:
# Named Entity Recognition: (S
#   first/RB
#   citizen/JJ
#   proceed/NN
#   hear/VBP
#   speak/JJ
#   speak/NN
#   speak/NN
#   first/RB
#   citizen/VBZ
#   resolved/VBN
#   rather/RB
#   die/JJ
#   famish/JJ
#   resolved/VBD
#   resolved/VBN
#   first/RB
#   citizen/JJ
#   first/RB
#   know/VBP
#   caius/JJ
#   marcius/NN
#   chief/JJ
#   enemy/NN
#   people/NNS
#   first/RB
#   citizen/VBP
#   let/VB
#   us/PRP
#   kill/VB
#   corn/NN
#   price/NN
#   verdict/NN
#   talking/VBG
#   let/VB
#   done/VBN
#   away/RB
#   away/RB
#   second/JJ
#   citizen/JJ
#   one/CD
#   word/NN
#   good/NN
#   citizens/NNS
#   first/JJ
#   citizen/RB
#   accounted/VBD
#   poor/JJ
#   citizens/NNS
#   patricians/NNS
#   good/JJ
#   authority/NN
#   surfeits/NNS
#   would/MD
#   relieve/VB
#   us/PRP
#   would/MD
#   yield/VB
#   us/PRP
#   superfluity/JJ
#   wholesome/NN
#   might/MD
#   guess/VB
#   relieved/VBD
#   us/PRP
#   humanely/RB
#   think/VBP
#   dear/JJ
#   leanness/NN
#   afflicts/VBZ
#   us/PRP
#   object/JJ
#   misery/NN
#   inventory/NN
#   particularise/NN
#   abundance/NN
#   sufferance/NN
#   gain/NN
#   let/VBD
#   us/PRP
#   revenge/VB
#   pikes/NNS
#   ere/RB
#   become/VBP
#   rakes/JJ
#   gods/NNS
#   know/VBP
#   speak/JJ
#   hunger/NN
#   bread/NN
#   thirst/JJ
#   revenge/NN
#   second/JJ
#   citizen/NN
#   would/MD
#   proceed/VB
#   especially/RB
#   caius/JJ
#   marcius/NNS
#   first/RB
#   dog/VBP
#   commonalty/NN
#   second/JJ
#   citizen/NN
#   consider/NN
#   services/NNS
#   done/VBN
#   country/NN
#   first/RB
#   citizen/VBZ
#   well/RB
#   could/MD
#   content/VB
#   give/VB
#   good/JJ
#   report/NN
#   fort/NN
#   pays/VBZ
#   proud/JJ
#   second/JJ
#   citizen/NN
#   nay/NN
#   speak/NN
#   maliciously/RB
#   first/JJ
#   citizen/NNS
#   say/VBP
#   unto/JJ
#   hath/NN
#   done/VBN
#   famously/RB
#   end/VB
#   though/IN
#   men/NNS
#   content/JJ
#   say/VBP
#   country/NN
#   please/VB
#   mother/RBR
#   partly/RB
#   proud/JJ
#   even/RB
#   till/VBP
#   altitude/VBP
#   virtue/JJ
#   second/JJ
#   citizen/NN
#   help/NN
#   nature/NN
#   account/NN
#   vice/NN
#   must/MD
#   way/NN
#   say/VBP
#   covetous/JJ
#   first/JJ
#   citizen/NN
#   must/MD
#   need/VB
#   barren/JJ
#   accusations/NNS
#   hath/NN
#   faults/NNS
#   surplus/VBP
#   tire/JJ
#   repetition/NN
#   shouts/NNS
#   side/VBP
#   city/NN
#   risen/NN
#   stay/VBP
#   prating/VBG
#   capitol/NN
#   come/VB
#   come/VBN
#   first/RB
#   citizen/JJ
#   soft/JJ
#   comes/VBZ
#   second/JJ
#   citizen/JJ
#   worthy/JJ
#   menenius/NN
#   agrippa/IN
#   one/CD
#   hath/NN
#   always/RB
#   loved/VBD
#   people/NNS
#   first/RB
#   citizen/VBP
#   one/CD
#   honest/JJS
#   enough/RB
#   would/MD
#   rest/VB
#   menenius/NN
#   work/NN
#   countrymen/NNS
#   hand/NN
#   go/VBP
#   bats/NNS
#   clubs/VBP
#   matter/NN
#   speak/NN
#   pray/NN
#   first/RB
#   citizen/JJ
#   business/NN
#   unknown/JJ
#   senate/NN
#   inkling/NN
#   fortnight/VBD
#   intend/JJ
#   show/NN
#   deeds/NNS
#   say/VBP
#   poor/JJ
#   suitors/NNS
#   strong/JJ
#   breaths/NNS
#   shall/MD
#   know/VB
#   strong/JJ
#   arms/NNS
#   menenius/NN
#   masters/NNS
#   good/JJ
#   friends/NNS
#   mine/VBP
#   honest/JJS
#   neighbours/NNS
#   undo/VBP
#   first/JJ
#   citizen/NN
#   sir/NN
#   undone/NN
#   already/RB
#   menenius/VBZ
#   tell/VB
#   friends/NNS
#   charitable/JJ
#   care/NN
#   patricians/NNS
#   wants/VBZ
#   suffering/VBG
#   dearth/NN
#   may/MD
#   well/RB
#   strike/VB
#   heaven/NN
#   staves/NNS
#   lift/VBP
#   roman/JJ
#   state/NN
#   whose/WP$
#   course/NN
#   way/NN
#   takes/VBZ
#   cracking/VBG
#   ten/NNS
#   thousand/VBP
#   curbs/NNS
#   strong/JJ
#   link/NN
#   asunder/NN
#   ever/RB
#   appear/VBP
#   impediment/JJ
#   dearth/NN
#   gods/NNS
#   patricians/NNS
#   make/VBP
#   knees/NNS
#   arms/NNS
#   must/MD
#   help/VB
#   alack/VB
#   transported/JJ
#   calamity/NN
#   thither/NN
#   attends/VBZ
#   slander/JJ
#   helms/NN
#   state/NN
#   care/NN
#   like/IN
#   fathers/NNS
#   curse/VBP
#   enemies/NNS
#   first/RB
#   citizen/VBP
#   care/VB
#   us/PRP
#   true/JJ
#   indeed/RB
#   cared/VBD
#   us/PRP
#   yet/RB
#   suffer/VBP
#   us/PRP
#   famish/JJ
#   crammed/VBD
#   grain/JJ
#   make/NN
#   edicts/NNS
#   usury/JJ
#   support/NN
#   usurers/NNS
#   repeal/VBP
#   daily/JJ
#   wholesome/NN
#   act/NN
#   established/VBD
#   rich/JJ
#   provide/IN
#   piercing/VBG
#   statutes/NNS
#   daily/RB
#   chain/NN
#   restrain/NN
#   poor/JJ
#   wars/NNS
#   eat/VBP
#   us/PRP
#   love/VB
#   bear/VBP
#   us/PRP
#   menenius/VBP
#   either/DT
#   must/MD
#   confess/RB
#   wondrous/JJ
#   malicious/JJ
#   accused/VBN
#   folly/RB
#   shall/MD
#   tell/VB
#   pretty/RB
#   tale/NN
#   may/MD
#   heard/VB
#   since/IN
#   serves/NNS
#   purpose/JJ
#   venture/NN
#   stale/JJ
#   little/JJ
#   first/JJ
#   citizen/NN
#   well/RB
#   hear/JJ
#   sir/NN
#   yet/RB
#   must/MD
#   think/VB
#   fob/JJ
#   disgrace/NN
#   tale/JJ
#   please/NN
#   deliver/VB
#   menenius/JJ
#   time/NN
#   body/NN
#   members/NNS
#   rebell/VBP
#   belly/RB
#   thus/RB
#   accused/VBN
#   like/IN
#   gulf/NN
#   remain/VBP
#   midst/JJ
#   body/NN
#   idle/JJ
#   unactive/JJ
#   still/RB
#   cupboarding/VBG
#   viand/NN
#   never/RB
#   bearing/VBG
#   like/IN
#   labour/JJ
#   rest/NN
#   instruments/NNS
#   see/VBP
#   hear/JJ
#   devise/NN
#   instruct/NN
#   walk/NN
#   feel/VB
#   mutually/RB
#   participate/JJ
#   minister/NN
#   unto/IN
#   appetite/JJ
#   affection/NN
#   common/JJ
#   whole/JJ
#   body/NN
#   belly/RB
#   answer/VBP
#   first/JJ
#   citizen/NN
#   well/RB
#   sir/RB
#   answer/JJR
#   made/VBN
#   belly/RB
#   menenius/JJ
#   sir/JJ
#   shall/MD
#   tell/VB
#   kind/NN
#   smile/NN
#   came/VBD
#   lungs/NNS
#   even/RB
#   thus/RB
#   look/NN
#   may/MD
#   make/VB
#   belly/RB
#   smile/JJ
#   well/RB
#   speak/JJ
#   tauntingly/RB
#   replied/VBD
#   discontented/JJ
#   members/NNS
#   mutinous/JJ
#   parts/NNS
#   envied/VBD
#   receipt/NN
#   even/RB
#   fitly/RB
#   malign/JJ
#   senators/NNS
#   first/RB
#   citizen/VBP
#   belly/RB
#   answer/JJR
#   head/NN
#   vigilant/NN
#   eye/NN
#   counsellor/NN
#   heart/NN
#   arm/NN
#   soldier/NN
#   steed/VBD
#   leg/JJ
#   tongue/NN
#   trumpeter/NN
#   muniments/NNS
#   petty/VBP
#   helps/VBZ
#   fabric/JJ
#   menenius/NN
#   fellow/NN
#   speaks/NNS
#   first/RB
#   citizen/VBP
#   cormorant/JJ
#   belly/RB
#   restrain/VBP
#   sink/VB
#   body/NN
#   menenius/RB
#   well/RB
#   first/RB
#   citizen/JJ
#   former/JJ
#   agents/NNS
#   complain/NN
#   could/MD
#   belly/RB
#   answer/VB
#   menenius/NN
#   tell/NN
#   bestow/IN
#   small/JJ
#   little/JJ
#   patience/NN
#   awhile/IN
#   hear/JJ
#   belly/RB
#   answer/VBP
#   first/JJ
#   citizen/JJ
#   ye/NN
#   long/JJ
#   menenius/JJ
#   note/NN
#   good/JJ
#   friend/NN
#   grave/VBP
#   belly/RB
#   deliberate/JJ
#   rash/NN
#   like/IN
#   accusers/NNS
#   thus/RB
#   answer/VBP
#   incorporate/JJ
#   friends/NNS
#   quoth/RB
#   receive/VBP
#   general/JJ
#   food/NN
#   first/RB
#   live/JJ
#   upon/NN
#   fit/NN
#   shop/NN
#   whole/JJ
#   body/NN
#   remember/VB
#   send/JJ
#   rivers/NNS
#   blood/VBD
#   even/RB
#   court/NN
#   heart/NN
#   seat/NN
#   brain/NN
#   cranks/NNS
#   offices/NNS
#   man/NN
#   strongest/VBP
#   nerves/NNS
#   small/JJ
#   inferior/JJ
#   veins/NNS
#   receive/VBP
#   natural/JJ
#   competency/NN
#   whereby/WRB
#   live/JJ
#   though/IN
#   good/JJ
#   friends/NNS
#   says/VBZ
#   belly/RB
#   mark/JJ
#   first/JJ
#   citizen/NN
#   ay/NN
#   sir/NN
#   well/RB
#   well/RB
#   menenius/VB
#   see/NN
#   deliver/NN
#   yet/RB
#   make/VB
#   audit/NN
#   back/RB
#   receive/JJ
#   flour/NN
#   leave/VBP
#   bran/NNS
#   say/VBP
#   first/JJ
#   citizen/NN
#   answer/NN
#   apply/VBP
#   menenius/JJ
#   senators/NNS
#   rome/VBP
#   good/JJ
#   belly/RB
#   mutinous/JJ
#   members/NNS
#   examine/VBP
#   counsels/NNS
#   cares/NNS
#   digest/VBP
#   things/NNS
#   rightly/RB
#   touching/VBG
#   weal/JJ
#   common/JJ
#   shall/MD
#   find/VB
#   public/JJ
#   benefit/NN
#   receive/JJ
#   proceeds/NNS
#   comes/VBZ
#   way/NN
#   think/VBP
#   great/JJ
#   toe/NN
#   assembly/NN
#   first/RB
#   citizen/VBZ
#   great/JJ
#   toe/JJ
#   great/JJ
#   toe/NN
#   menenius/NN
#   one/CD
#   lowest/JJS
#   basest/NN
#   poorest/NN
#   wise/NN
#   rebellion/NN
#   thou/NN
#   foremost/NN
#   thou/JJ
#   rascal/JJ
#   art/NN
#   worst/JJS
#   blood/NN
#   run/NN
#   first/RB
#   win/JJ
#   vantage/NN
#   make/VBP
#   ready/JJ
#   stiff/JJ
#   bats/NNS
#   clubs/VBP
#   rome/JJ
#   rats/NNS
#   point/VBP
#   battle/NN
#   one/CD
#   side/NN
#   must/MD
#   bale/VB
#   hail/NN
#   noble/JJ
#   marcius/NN
#   marcius/NN
#   thanks/NNS
#   matter/RBR
#   dissentious/JJ
#   rogues/NNS
#   rubbing/VBG
#   poor/JJ
#   itch/JJ
#   opinion/NN
#   make/VBP
#   scabs/NNS
#   first/RB
#   citizen/VBP
#   ever/RB
#   good/JJ
#   word/NN
#   marcius/NN
#   give/VBP
#   good/JJ
#   words/NNS
#   thee/VBP
#   flatter/JJ
#   beneath/NN
#   abhorring/VBG
#   would/MD
#   curs/VB
#   like/IN
#   peace/NN
#   war/NN
#   one/CD
#   affrights/NN
#   makes/VBZ
#   proud/JJ
#   trusts/NNS
#   find/VBP
#   lions/NNS
#   finds/VBZ
#   hares/NNS
#   foxes/VBP
#   geese/JJ
#   surer/NN
#   coal/NN
#   fire/NN
#   upon/IN
#   ice/NN
#   hailstone/NN
#   sun/NN
#   virtue/NN
#   make/VBP
#   worthy/JJ
#   whose/WP$
#   offence/NN
#   subdues/VBZ
#   curse/JJ
#   justice/NN
#   deserves/NNS
#   greatness/VBP
#   deserves/NNS
#   hate/VBP
#   affections/NNS
#   sick/JJ
#   man/NN
#   appetite/NN
#   desires/NNS
#   would/MD
#   increase/VB
#   evil/JJ
#   depends/VBZ
#   upon/JJ
#   favours/NNS
#   swims/VBP
#   fins/NNS
#   lead/JJ
#   hews/NNS
#   oaks/JJ
#   rushes/NNS
#   hang/VBP
#   ye/JJ
#   trust/NN
#   ye/NN
#   every/DT
#   minute/NN
#   change/NN
#   mind/NN
#   call/NN
#   noble/JJ
#   hate/NN
#   vile/NN
#   garland/VBP
#   matter/NN
#   several/JJ
#   places/NNS
#   city/NN
#   cry/NN
#   noble/JJ
#   senate/NN
#   gods/NNS
#   keep/VB
#   awe/NN
#   else/RB
#   would/MD
#   feed/VB
#   one/CD
#   another/DT
#   seeking/VBG
#   menenius/NN
#   corn/NN
#   rates/NNS
#   whereof/VBP
#   say/VBP
#   city/NN
#   well/RB
#   stored/VBD
#   marcius/NNS
#   hang/NNS
#   say/VBP
#   sit/NN
#   fire/NN
#   presume/NN
#   know/VBP
#   done/VBN
#   capitol/NN
#   like/IN
#   rise/NN
#   thrives/NNS
#   declines/NNS
#   side/VBP
#   factions/NNS
#   give/VBP
#   conjectural/JJ
#   marriages/NNS
#   making/VBG
#   parties/NNS
#   strong/JJ
#   feebling/JJ
#   stand/NN
#   liking/VBG
#   cobbled/VBD
#   shoes/NNS
#   say/VB
#   grain/NN
#   enough/RB
#   would/MD
#   nobility/VB
#   lay/VB
#   aside/RB
#   ruth/JJ
#   let/NN
#   use/NN
#   sword/VB
#   make/NN
#   quarry/NN
#   thousands/NNS
#   quarter/NN
#   slaves/NNS
#   high/RB
#   could/MD
#   pick/VB
#   lance/NN
#   menenius/NN
#   nay/VBZ
#   almost/RB
#   thoroughly/RB
#   persuaded/VBN
#   though/IN
#   abundantly/RB
#   lack/JJ
#   discretion/NN
#   yet/RB
#   passing/VBG
#   cowardly/RB
#   beseech/JJ
#   says/VBZ
#   troop/NN
#   marcius/NN
#   dissolved/VBD
#   hang/NN
#   said/VBD
#   sigh/JJ
#   forth/NN
#   proverbs/NN
#   hunger/NN
#   broke/VBD
#   stone/NN
#   walls/NNS
#   dogs/NNS
#   must/MD
#   eat/VB
#   meat/NN
#   made/VBN
#   mouths/NNS
#   gods/NNS
#   sent/VBD
#   corn/NN
#   rich/JJ
#   men/NNS
#   shreds/NNS
#   vented/VBD
#   complainings/NNS
#   answer/JJR
#   petition/NN
#   granted/VBD
#   strange/JJ
#   one/CD
#   break/NN
#   heart/NN
#   generosity/NN
#   make/VBP
#   bold/JJ
#   power/NN
#   look/NN
#   pale/JJ
#   threw/NN
#   caps/NNS
#   would/MD
#   hang/VB
#   horns/NNS
#   moon/RB
#   shouting/VBG
#   emulation/NN
#   menenius/NN
#   granted/VBD
#   marcius/JJ
#   five/CD
#   tribunes/NNS
#   defend/VBP
#   vulgar/NN
#   wisdoms/NNS
#   choice/NN
#   one/CD
#   junius/NN
#   brutus/NN
#   sicinius/NN
#   velutus/NN
#   know/VBP
#   rabble/JJ
#   first/JJ
#   unroof/JJ
#   city/NN
#   ere/RB
#   prevail/JJ
#   time/NN
#   win/VB
#   upon/JJ
#   power/NN
#   throw/NN
#   forth/NN
#   greater/JJR
#   themes/NNS
#   insurrection/VBP
#   arguing/VBG
#   menenius/NN
#   strange/JJ
#   marcius/NN
#   go/VBP
#   get/VB
#   home/NN
#   fragments/NNS
#   messenger/RBR
#   caius/JJ
#   marcius/NN
#   marcius/NN
#   matter/NN
#   messenger/NN
#   news/NN
#   sir/NN
#   volsces/NNS
#   arms/NNS
#   marcius/NN
#   glad/VBP
#   shall/MD
#   ha/VB
#   means/NNS
#   vent/JJ
#   musty/JJ
#   superfluity/NN
#   see/VBP
#   best/JJS
#   elders/NNS
#   first/RB
#   senator/JJ
#   marcius/NN
#   true/JJ
#   lately/RB
#   told/VBD
#   us/PRP
#   volsces/NNS
#   arms/NNS
#   marcius/JJ
#   leader/NN
#   tullus/NN
#   aufidius/NN
#   put/VBD
#   sin/JJ
#   envying/VBG
#   nobility/JJ
#   thing/NN
#   would/MD
#   wish/VB
#   cominius/NN
#   fought/VBN
#   together/RB
#   marcius/JJ
#   half/NN
#   half/NN
#   world/NN
#   ears/VBZ
#   upon/IN
#   party/NN
#   revolt/NNS
#   make/VBP
#   wars/NNS
#   lion/JJ
#   proud/NN
#   hunt/NN
#   first/RB
#   senator/NN
#   worthy/JJ
#   marcius/NN
#   attend/VBP
#   upon/IN
#   cominius/NN
#   wars/NNS
#   cominius/VBP
#   former/JJ
#   promise/NN
#   marcius/NN
#   sir/NN
#   constant/JJ
#   titus/NN
#   lartius/NN
#   thou/NN
#   shalt/NN
#   see/VBP
#   strike/NN
#   tullus/CC
#   face/JJ
#   art/NN
#   thou/NN
#   stiff/NN
#   titus/NN
#   caius/NN
#   marcius/NN
#   lean/JJ
#   upon/IN
#   one/CD
#   crutch/NN
#   fight/NN
#   ere/RB
#   stay/VBN
#   behind/IN
#   business/NN
#   menenius/NNS
#   first/RB
#   senator/VBP
#   company/NN
#   capitol/NN
#   know/VBP
#   greatest/JJS
#   friends/NNS
#   attend/VBP
#   us/PRP
#   titus/JJ
#   cominius/NN
#   noble/JJ
#   marcius/NN
#   first/RB
#   senator/JJ
#   marcius/NN
#   nay/JJ
#   let/NN
#   follow/VB
#   volsces/NNS
#   much/JJ
#   corn/NN
#   take/VB
#   rats/NNS
#   thither/RB
#   gnaw/JJ
#   garners/NNS
#   worshipful/JJ
#   mutiners/NNS
#   valour/VBP
#   puts/RB
#   well/RB
#   forth/JJ
#   pray/NN
#   follow/NN
#   sicinius/NN
#   ever/RB
#   man/NN
#   proud/JJ
#   marcius/NN
#   brutus/NN
#   equal/JJ
#   sicinius/NN
#   chosen/VBN
#   tribunes/NNS
#   people/NNS
#   brutus/VBP
#   mark/NN
#   lip/JJ
#   eyes/NNS
#   sicinius/VBP
#   nay/JJ
#   taunts/NNS
#   brutus/VBP
#   moved/VBN
#   spare/JJ
#   gird/JJ
#   gods/NNS
#   sicinius/VBP
#   modest/JJ
#   moon/NN
#   brutus/NN
#   present/JJ
#   wars/NNS
#   devour/VBP
#   grown/JJ
#   proud/NN
#   valiant/JJ
#   sicinius/JJ
#   nature/NN
#   tickled/VBD
#   good/JJ
#   success/NN
#   disdains/NNS
#   shadow/VBP
#   treads/NNS
#   noon/RB
#   wonder/VBP
#   insolence/NN
#   brook/NN
#   commanded/VBD
#   cominius/NN
#   brutus/NN
#   fame/NN
#   aims/VBZ
#   already/RB
#   well/RB
#   graced/VBN
#   better/JJR
#   held/VBN
#   attain/JJ
#   place/NN
#   first/JJ
#   miscarries/NNS
#   shall/MD
#   general/JJ
#   fault/NN
#   though/IN
#   perform/NN
#   utmost/NN
#   man/NN
#   giddy/JJ
#   censure/NN
#   cry/NN
#   marcius/JJ
#   borne/NN
#   business/NN
#   sicinius/NN
#   besides/IN
#   things/NNS
#   go/VBP
#   well/RB
#   opinion/NN
#   sticks/NNS
#   marcius/VBP
#   shall/MD
#   demerits/NNS
#   rob/VB
#   cominius/NN
#   brutus/NN
#   come/VBP
#   half/NN
#   cominius/NN
#   honours/VBZ
#   marcius/CC
#   though/IN
#   marcius/NN
#   earned/VBN
#   faults/NNS
#   marcius/RBR
#   shall/MD
#   honours/VB
#   though/IN
#   indeed/RB
#   aught/JJ
#   merit/NN
#   sicinius/NN
#   let/VBD
#   hence/RB
#   hear/JJ
#   dispatch/NN
#   made/VBN
#   fashion/NN
#   singularity/NN
#   goes/VBZ
#   upon/IN
#   present/JJ
#   action/NN
#   brutus/NN
#   lets/NNS
#   along/IN
#   first/JJ
#   senator/NN
#   opinion/NN
#   aufidius/IN
#   rome/NN
#   entered/VBD
#   counsels/NNS
#   know/VBP
#   proceed/VBP
#   aufidius/JJ
#   ever/RB
#   thought/VBN
#   state/NN
#   could/MD
#   brought/VB
#   bodily/RB
#   act/NN
#   ere/JJ
#   rome/JJ
#   circumvention/NN
#   four/CD
#   days/NNS
#   gone/VBN
#   since/IN
#   heard/NN
#   thence/NN
#   words/NNS
#   think/VBP
#   letter/NN
#   yes/RB
#   press/JJ
#   power/NN
#   known/IN
#   whether/IN
#   east/JJ
#   west/JJ
#   dearth/NN
#   great/JJ
#   people/NNS
#   mutinous/JJ
#   rumour/JJ
#   cominius/NN
#   marcius/NN
#   old/JJ
#   enemy/NN
#   rome/NN
#   worse/NN
#   hated/VBD
#   titus/JJ
#   lartius/NN
#   valiant/NN
#   roman/NN
#   three/CD
#   lead/JJ
#   preparation/NN
#   whither/NN
#   bent/NN
#   likely/RB
#   consider/VB
#   first/JJ
#   senator/NN
#   army/NN
#   field/NN
#   never/RB
#   yet/RB
#   made/VBN
#   doubt/NN
#   rome/VB
#   ready/JJ
#   answer/VB
#   us/PRP
#   aufidius/JJ
#   think/VBP
#   folly/RB
#   keep/VB
#   great/JJ
#   pretences/NNS
#   veil/VBP
#   till/JJ
#   needs/NNS
#   must/MD
#   show/VB
#   hatching/VBG
#   seem/JJ
#   appear/JJ
#   rome/NN
#   discovery/NN
#   shall/MD
#   shorten/VB
#   aim/JJ
#   take/VB
#   many/JJ
#   towns/NNS
#   ere/RB
#   almost/RB
#   rome/VB
#   know/JJ
#   afoot/JJ
#   second/JJ
#   senator/NN
#   noble/JJ
#   aufidius/NNS
#   take/VBP
#   commission/NN
#   hie/NN
#   bands/VBZ
#   let/VB
#   us/PRP
#   alone/RB
#   guard/VBP
#   corioli/JJ
#   set/VBN
#   remove/VB
#   bring/JJ
#   army/NN
#   think/VBP
#   find/VB
#   prepared/JJ
#   us/PRP
#   aufidius/VBP
#   doubt/JJ
#   speak/JJ
#   certainties/NNS
#   nay/VBP
#   parcels/NNS
#   power/NN
#   forth/NN
#   already/RB
#   hitherward/RB
#   leave/VBP
#   honours/NNS
#   caius/JJ
#   marcius/JJ
#   chance/NN
#   meet/NN
#   sworn/VBD
#   us/PRP
#   shall/MD
#   ever/RB
#   strike/VB
#   till/NN
#   one/CD
#   gods/NNS
#   assist/JJ
#   aufidius/JJ
#   keep/NN
#   honours/NN
#   safe/JJ
#   first/JJ
#   senator/NN
#   farewell/VBP
#   second/JJ
#   senator/NN
#   farewell/NN
#   farewell/RB
#   volumnia/RB
#   pray/JJ
#   daughter/NN
#   sing/VBG
#   express/CC
#   comfortable/JJ
#   sort/NN
#   son/NN
#   husband/NN
#   freelier/NN
#   rejoice/NN
#   absence/NN
#   wherein/VBD
#   honour/JJ
#   embracements/NNS
#   bed/VBD
#   would/MD
#   show/VB
#   love/VB
#   yet/RB
#   son/JJ
#   womb/NN
#   youth/NN
#   comeliness/NN
#   plucked/VBD
#   gaze/JJ
#   way/NN
#   day/NN
#   kings/VB
#   entreaties/VBZ
#   mother/RB
#   sell/VB
#   hour/NN
#   beholding/VBG
#   considering/VBG
#   honour/NN
#   would/MD
#   become/VB
#   person/NN
#   better/RBR
#   hang/NN
#   wall/NN
#   renown/NN
#   made/VBD
#   stir/NNS
#   pleased/JJ
#   let/NN
#   seek/VB
#   danger/NN
#   like/IN
#   find/NN
#   fame/JJ
#   cruel/JJ
#   war/NN
#   sent/VBD
#   whence/NN
#   returned/VBN
#   brows/NNS
#   bound/IN
#   oak/NN
#   tell/NN
#   thee/NN
#   daughter/NN
#   sprang/NN
#   joy/NN
#   first/RB
#   hearing/VBG
#   first/JJ
#   seeing/VBG
#   proved/JJ
#   man/NN
#   virgilia/NN
#   died/VBD
#   business/NN
#   madam/NN
#   volumnia/NN
#   good/JJ
#   report/NN
#   son/NN
#   therein/NN
#   would/MD
#   found/VB
#   issue/NN
#   hear/JJ
#   profess/NN
#   sincerely/RB
#   dozen/NN
#   sons/NNS
#   love/VBP
#   alike/RB
#   none/NN
#   less/JJR
#   dear/JJ
#   thine/NN
#   good/JJ
#   marcius/NN
#   rather/RB
#   eleven/RB
#   die/VB
#   nobly/RB
#   country/NN
#   one/CD
#   voluptuously/RB
#   surfeit/JJ
#   action/NN
#   gentlewoman/NN
#   madam/NN
#   lady/NN
#   valeria/NNS
#   come/VBP
#   visit/NN
#   virgilia/NNS
#   beseech/VBP
#   give/JJ
#   leave/VBP
#   retire/VBN
#   volumnia/NN
#   indeed/RB
#   shall/MD
#   methinks/VB
#   hear/VB
#   hither/JJ
#   husband/NN
#   drum/NN
#   see/VBP
#   pluck/JJ
#   aufidius/JJ
#   hair/NN
#   children/NNS
#   bear/VBP
#   volsces/NNS
#   shunning/VBG
#   methinks/NNS
#   see/VBP
#   stamp/JJ
#   thus/RB
#   call/NN
#   thus/RB
#   cowards/NNS
#   got/VBD
#   fear/JJ
#   though/IN
#   born/JJ
#   rome/NN
#   bloody/NN
#   brow/JJ
#   mail/NN
#   hand/NN
#   wiping/VBG
#   forth/NN
#   goes/VBZ
#   like/IN
#   task/NN
#   mow/NN
#   lose/VBP
#   hire/NN
#   virgilia/NN
#   bloody/NN
#   brow/VBP
#   jupiter/NN
#   blood/NN
#   volumnia/NN
#   away/RB
#   fool/JJ
#   becomes/NNS
#   man/NN
#   gilt/VBP
#   trophy/NN
#   breasts/NNS
#   hecuba/VBP
#   suckle/JJ
#   hector/NN
#   look/NN
#   lovelier/JJR
#   hector/NN
#   forehead/NN
#   spit/VBD
#   forth/JJ
#   blood/NN
#   grecian/JJ
#   sword/NN
#   contemning/VBG
#   tell/NN
#   valeria/NNS
#   fit/VBP
#   bid/NN
#   welcome/JJ
#   virgilia/NN
#   heavens/NNS
#   bless/NN
#   lord/NN
#   fell/VBD
#   aufidius/RB
#   volumnia/JJ
#   beat/NN
#   aufidius/JJ
#   knee/NN
#   tread/NN
#   upon/IN
#   neck/NN
#   valeria/NN
#   ladies/NNS
#   good/JJ
#   day/NN
#   volumnia/NNP
#   sweet/NN
#   madam/NN
#   virgilia/NN
#   glad/NN
#   see/VBP
#   ladyship/JJ
#   valeria/NNS
#   manifest/JJS
#   sewing/VBG
#   fine/JJ
#   spot/NN
#   good/JJ
#   faith/NN
#   little/JJ
#   son/NN
#   virgilia/NNS
#   thank/VBD
#   ladyship/RB
#   well/RB
#   good/JJ
#   madam/NNS
#   volumnia/VBP
#   rather/RB
#   see/VB
#   swords/NNS
#   hear/VB
#   drum/JJ
#   look/NN
#   upon/IN
#   valeria/NN
#   word/NN
#   father/NN
#   son/NN
#   swear/JJ
#   pretty/RB
#   boy/JJ
#   troth/NN
#   looked/VBD
#   upon/IN
#   wednesday/JJ
#   half/JJ
#   hour/NN
#   together/RB
#   confirmed/VBD
#   countenance/NN
#   saw/NN
#   run/NN
#   gilded/VBD
#   butterfly/NN
#   caught/NN
#   let/NN
#   go/VB
#   comes/VBZ
#   catched/RB
#   whether/IN
#   fall/NN
#   enraged/VBD
#   set/VBN
#   teeth/NNS
#   tear/JJ
#   warrant/NN
#   mammocked/VBD
#   volumnia/JJ
#   one/CD
#   father/NN
#   moods/NNS
#   valeria/VBP
#   indeed/RB
#   la/RBR
#   noble/JJ
#   child/NN
#   virgilia/NNS
#   crack/VBP
#   madam/JJ
#   valeria/NNS
#   come/VBP
#   lay/JJ
#   aside/JJ
#   stitchery/NN
#   must/MD
#   play/VB
#   idle/JJ
#   husewife/NN
#   afternoon/NN
#   virgilia/RB
#   good/JJ
#   madam/NN
#   doors/NNS
#   valeria/VBP
#   doors/NNS
#   volumnia/VBP
#   shall/MD
#   shall/MD
#   virgilia/VB
#   indeed/RB
#   patience/NN
#   threshold/NN
#   till/NN
#   lord/VBZ
#   return/NN
#   wars/NNS
#   valeria/VBP
#   fie/JJ
#   confine/NN
#   unreasonably/RB
#   come/VB
#   must/MD
#   go/VB
#   visit/RB
#   good/JJ
#   lady/NN
#   lies/VBZ
#   virgilia/JJ
#   wish/JJ
#   speedy/NN
#   strength/NN
#   visit/NN
#   prayers/NNS
#   go/VBP
#   thither/RB
#   volumnia/RB
#   pray/JJ
#   virgilia/NNS
#   save/VBP
#   labour/VBN
#   want/VBP
#   love/NN
#   valeria/NN
#   would/MD
#   another/DT
#   penelope/NN
#   yet/RB
#   say/VBP
#   yarn/UH
#   spun/JJ
#   ulysses/NNS
#   absence/NN
#   fill/NN
#   ithaca/VBP
#   full/JJ
#   moths/NNS
#   come/VBN
#   would/MD
#   cambric/VB
#   sensible/JJ
#   finger/NN
#   might/MD
#   leave/VB
#   pricking/VBG
#   pity/NN
#   come/VB
#   shall/MD
#   go/VB
#   us/PRP
#   virgilia/RB
#   good/JJ
#   madam/NN
#   pardon/NNS
#   indeed/RB
#   forth/VBP
#   valeria/NNS
#   truth/NN
#   la/VBP
#   go/VB
#   tell/JJ
#   excellent/JJ
#   news/NN
#   husband/NN
#   virgilia/RB
#   good/JJ
#   madam/NN
#   none/NN
#   yet/RB
#   valeria/VBN
#   verily/RB
#   jest/JJS
#   came/VBD
#   news/NN
#   last/JJ
#   night/NN
#   virgilia/NNS
#   indeed/RB
#   madam/VBP
#   valeria/NNS
#   earnest/VBP
#   true/JJ
#   heard/NN
#   senator/NN
#   speak/NN
#   thus/RB
#   volsces/NNS
#   army/VBP
#   forth/NN
#   cominius/NN
#   general/JJ
#   gone/VBN
#   one/CD
#   part/NN
#   roman/NN
#   power/NN
#   lord/NN
#   titus/NN
#   lartius/NN
#   set/VBN
#   city/NN
#   corioli/NN
#   nothing/NN
#   doubt/NN
#   prevailing/VBG
#   make/VBP
#   brief/JJ
#   wars/NNS
#   true/JJ
#   mine/VBP
#   honour/NN
#   pray/NN
#   go/VBP
#   us/PRP
#   virgilia/RB
#   give/VBP
#   excuse/RB
#   good/JJ
#   madam/NN
#   obey/NN
#   every/DT
#   thing/NN
#   hereafter/NN
#   volumnia/NN
#   let/VB
#   alone/RB
#   lady/JJ
#   disease/NN
#   better/RBR
#   mirth/NN
#   valeria/NNS
#   troth/DT
#   think/VBP
#   would/MD
#   fare/VB
#   well/RB
#   come/RB
#   good/JJ
#   sweet/JJ
#   lady/NN
#   prithee/NN
#   virgilia/FW
#   turn/NN
#   thy/JJ
#   solemness/NN
#   door/NN
#   go/VBP
#   along/IN
#   us/PRP
#   virgilia/VBP
#   word/NN
#   madam/NN
#   indeed/RB
#   must/MD
#   wish/VB
#   much/JJ
#   mirth/NN
#   valeria/NNS
#   well/RB
#   farewell/RB
#   marcius/JJ
#   yonder/NN
#   comes/VBZ
#   news/NN
#   wager/NN
#   met/VBD
#   lartius/JJ
#   horse/NN
#   marcius/NN
#   done/VBN
#   lartius/JJ
#   agreed/VBD
#   marcius/NNS
#   say/VBP
#   general/JJ
#   met/VBD
#   enemy/JJ
#   messenger/NN
#   lie/NN
#   view/NN
#   spoke/VBD
#   yet/RB
#   lartius/JJ
#   good/JJ
#   horse/NN
#   mine/NN
#   marcius/NN
#   buy/VB
#   lartius/JJ
#   sell/NN
#   give/VBP
#   lend/NN
#   half/NN
#   hundred/CD
#   years/NNS
#   summon/JJ
#   town/NN
#   marcius/NN
#   far/RB
#   lie/JJ
#   armies/NNS
#   messenger/NN
#   within/IN
#   mile/JJ
#   half/NN
#   marcius/JJ
#   shall/MD
#   hear/VB
#   mars/NNS
#   prithee/VB
#   make/VBP
#   us/PRP
#   quick/JJ
#   work/NN
#   smoking/NN
#   swords/NNS
#   may/MD
#   march/VB
#   hence/NN
#   help/NN
#   fielded/VBD
#   friends/NNS
#   come/VBP
#   blow/NN
#   thy/NN
#   blast/NN
#   tutus/NN
#   aufidius/NN
#   within/IN
#   walls/NNS
#   first/JJ
#   senator/NN
#   man/NN
#   fears/VBZ
#   less/JJR
#   lesser/JJ
#   little/JJ
#   hark/NN
#   drums/NNS
#   bringing/VBG
#   forth/JJ
#   youth/RB
#   break/VBP
#   walls/NNS
#   rather/RB
#   shall/MD
#   pound/NN
#   us/PRP
#   gates/VBZ
#   yet/RB
#   seem/JJ
#   shut/NN
#   pinn/NN
#   rushes/NNS
#   open/JJ
#   hark/NN
#   far/RB
#   aufidius/JJ
#   list/JJ
#   work/NN
#   makes/VBZ
#   amongst/RB
#   cloven/JJ
#   army/NN
#   marcius/NN
#   lartius/NN
#   noise/NN
#   instruction/NN
#   ladders/NNS
#   ho/VBP
#   marcius/JJ
#   fear/VBP
#   us/PRP
#   issue/VB
#   forth/JJ
#   city/NN
#   put/VBD
#   shields/NNS
#   hearts/NNS
#   fight/VBD
#   hearts/NNS
#   proof/NN
#   shields/NNS
#   advance/RB
#   brave/VBP
#   titus/NN
#   disdain/VBP
#   us/PRP
#   much/JJ
#   beyond/IN
#   thoughts/NNS
#   makes/VBZ
#   sweat/NN
#   wrath/JJ
#   come/NN
#   fellows/VBZ
#   retires/NNS
#   take/VB
#   volsce/NNS
#   shall/MD
#   feel/VB
#   mine/JJ
#   edge/NN
#   marcius/NN
#   contagion/NN
#   south/RB
#   light/JJ
#   shames/NNS
#   rome/VBP
#   herd/NN
#   boils/NNS
#   plagues/NNS
#   plaster/NN
#   may/MD
#   seen/VBN
#   one/CD
#   infect/NN
#   another/DT
#   wind/NN
#   mile/NN
#   souls/NNS
#   geese/JJ
#   bear/VBP
#   shapes/NNS
#   men/NNS
#   run/VBP
#   slaves/NNS
#   apes/NNS
#   would/MD
#   beat/VB
#   pluto/NN
#   hell/NN
#   hurt/VBD
#   behind/IN
#   backs/NNS
#   red/JJ
#   faces/VBZ
#   pale/JJ
#   flight/NN
#   agued/VBN
#   fear/JJ
#   mend/JJ
#   charge/NN
#   home/NN
#   fires/NNS
#   heaven/VBN
#   leave/VBP
#   foe/NNS
#   make/VBP
#   wars/NNS
#   look/VB
#   come/JJ
#   stand/NN
#   fast/RB
#   beat/JJ
#   wives/NNS
#   us/PRP
#   trenches/VBP
#   followed/VBN
#   gates/NNS
#   ope/IN
#   prove/RB
#   good/JJ
#   seconds/NNS
#   followers/NNS
#   fortune/VBP
#   widens/VBZ
#   fliers/NNS
#   mark/VBP
#   like/IN
#   first/JJ
#   soldier/JJR
#   second/JJ
#   soldier/JJR
#   first/JJ
#   soldier/JJR
#   see/NN
#   shut/NN
#   pot/NN
#   warrant/NN
#   lartius/VBZ
#   become/VBN
#   marcius/JJ
#   slain/NN
#   sir/NN
#   doubtless/NN
#   first/RB
#   soldier/RBR
#   following/VBG
#   fliers/NNS
#   heels/NNS
#   enters/NNS
#   upon/IN
#   sudden/JJ
#   clapp/NN
#   gates/NNS
#   alone/RB
#   answer/VBP
#   city/NN
#   lartius/NN
#   noble/JJ
#   fellow/NN
#   sensibly/RB
#   outdares/VBZ
#   senseless/JJ
#   sword/NN
#   bows/VBZ
#   stands/VBZ
#   thou/JJ
#   art/NN
#   left/VBD
#   marcius/JJ
#   carbuncle/NN
#   entire/JJ
#   big/JJ
#   thou/NN
#   art/NN
#   rich/JJ
#   jewel/NN
#   thou/NN
#   wast/NN
#   soldier/VBD
#   even/RB
#   cato/JJ
#   wish/JJ
#   fierce/NN
#   terrible/JJ
#   strokes/NNS
#   thy/JJ
#   grim/JJ
#   looks/VBZ
#   percussion/NN
#   thy/JJ
#   sounds/VBZ
#   thou/JJ
#   madst/FW
#   thine/NN
#   enemies/NNS
#   shake/VBP
#   world/NN
#   feverous/JJ
#   tremble/JJ
#   first/JJ
#   soldier/JJR
#   look/NN
#   sir/JJ
#   lartius/NN
#   marcius/NN
#   let/VBD
#   fetch/VB
#   make/VB
#   remain/NN
#   alike/IN
#   first/JJ
#   roman/NN
#   carry/VBP
#   rome/JJ
#   second/JJ
#   roman/JJ
#   third/JJ
#   roman/NN
#   murrain/NN
#   took/VBD
#   silver/NN
#   marcius/NN
#   see/VBP
#   movers/NNS
#   prize/VB
#   hours/NNS
#   crack/VB
#   drachm/JJ
#   cushions/NNS
#   leaden/JJ
#   spoons/NNS
#   irons/NNS
#   doit/VBP
#   doublets/NNS
#   hangmen/NNS
#   would/MD
#   bury/VB
#   wore/IN
#   base/NN
#   slaves/NNS
#   ere/RB
#   yet/RB
#   fight/VBN
#   done/VBN
#   pack/NN
#   hark/NN
#   noise/NN
#   general/JJ
#   makes/VBZ
#   man/NN
#   soul/NN
#   hate/NN
#   aufidius/IN
#   piercing/VBG
#   romans/NNS
#   valiant/JJ
#   titus/NNS
#   take/VBP
#   convenient/JJ
#   numbers/NNS
#   make/VBP
#   good/JJ
#   city/NN
#   whilst/NN
#   spirit/NN
#   haste/NN
#   help/NN
#   cominius/VB
#   lartius/JJ
#   worthy/JJ
#   sir/NN
#   thou/NN
#   thy/JJ
#   exercise/NN
#   hath/NN
#   violent/JJ
#   second/JJ
#   course/NN
#   fight/NN
#   marcius/NN
#   sir/NN
#   praise/NN
#   work/NN
#   hath/NN
#   yet/RB
#   warm/JJ
#   fare/NN
#   well/RB
#   blood/RB
#   drop/NN
#   rather/RB
#   physical/JJ
#   dangerous/JJ
#   aufidius/NN
#   thus/RB
#   appear/JJ
#   fight/NN
#   lartius/NN
#   fair/JJ
#   goddess/NN
#   fortune/NN
#   fall/NN
#   deep/JJ
#   love/NN
#   thee/NN
#   great/JJ
#   charms/NNS
#   misguide/VBP
#   thy/JJ
#   opposers/NNS
#   swords/NNS
#   bold/JJ
#   gentleman/JJ
#   prosperity/NN
#   thy/JJ
#   page/NN
#   marcius/NN
#   thy/JJ
#   friend/NN
#   less/JJR
#   placeth/JJ
#   highest/JJS
#   farewell/NN
#   lartius/NN
#   thou/NN
#   worthiest/JJS
#   marcius/NN
#   go/VBP
#   sound/JJ
#   thy/JJ
#   trumpet/NN
#   call/NN
#   thither/NN
#   officers/NNS
#   town/NN
#   shall/MD
#   know/VB
#   mind/VB
#   away/RP
#   cominius/JJ
#   breathe/NN
#   friends/NNS
#   well/RB
#   fought/RB
#   come/VBN
#   like/IN
#   romans/NNS
#   neither/CC
#   foolish/JJ
#   stands/NNS
#   cowardly/RB
#   retire/VBP
#   believe/VBP
#   sirs/NNS
#   shall/MD
#   charged/VBN
#   whiles/NNS
#   struck/VBD
#   interims/NNS
#   conveying/VBG
#   gusts/NNS
#   heard/VBD
#   charges/NNS
#   friends/NNS
#   ye/VBP
#   roman/JJ
#   gods/NNS
#   lead/VBP
#   successes/NNS
#   wish/JJ
#   powers/NNS
#   smiling/VBG
#   fronts/NNS
#   encountering/VBG
#   may/MD
#   give/VB
#   thankful/JJ
#   sacrifice/NN
#   thy/JJ
#   news/NN
#   messenger/NN
#   citizens/NNS
#   corioli/VBP
#   issued/VBN
#   given/VBN
#   lartius/RBR
#   marcius/JJ
#   battle/NN
#   saw/VBD
#   party/NN
#   trenches/NNS
#   driven/VBN
#   came/VBD
#   away/RB
#   cominius/JJ
#   though/IN
#   thou/JJ
#   truth/NN
#   methinks/NNS
#   thou/RB
#   well/RB
#   long/RB
#   since/IN
#   messenger/JJR
#   hour/NN
#   lord/NN
#   cominius/NN
#   mile/NN
#   briefly/NN
#   heard/VBD
#   drums/NNS
#   couldst/JJ
#   thou/NN
#   mile/NN
#   confound/VBD
#   hour/NN
#   bring/NN
#   thy/JJ
#   news/NN
#   late/RB
#   messenger/NN
#   spies/NNS
#   volsces/NNS
#   held/VBD
#   chase/RB
#   forced/VBN
#   wheel/VBP
#   three/CD
#   four/CD
#   miles/NNS
#   else/RB
#   sir/VBP
#   half/JJ
#   hour/NN
#   since/IN
#   brought/VBN
#   report/NN
#   cominius/NN
#   yonder/NN
#   appear/VBP
#   flay/VBN
#   gods/NNS
#   stamp/VBP
#   marcius/NN
#   seen/VBN
#   thus/RB
#   marcius/JJ
#   cominius/NN
#   shepherd/NN
#   knows/VBZ
#   thunder/VB
#   tabour/NNS
#   know/VBP
#   sound/JJ
#   marcius/JJ
#   tongue/NN
#   every/DT
#   meaner/NN
#   man/NN
#   marcius/VBZ
#   come/VBN
#   late/JJ
#   cominius/NN
#   ay/VBZ
#   come/VBN
#   blood/NN
#   others/NNS
#   mantled/VBD
#   marcius/JJ
#   let/NN
#   clip/NN
#   ye/VB
#   arms/NNS
#   sound/JJ
#   woo/JJ
#   heart/NN
#   merry/NN
#   nuptial/JJ
#   day/NN
#   done/VBN
#   tapers/NNS
#   burn/VBP
#   bedward/JJ
#   cominius/NN
#   flower/NN
#   warriors/NNS
#   titus/VBP
#   lartius/JJ
#   marcius/NN
#   man/NN
#   busied/VBD
#   decrees/NNS
#   condemning/VBG
#   death/NN
#   exile/NN
#   ransoming/VBG
#   pitying/VBG
#   threatening/VBG
#   holding/VBG
#   corioli/NN
#   name/NN
#   rome/VBD
#   even/RB
#   like/IN
#   fawning/VBG
#   greyhound/NN
#   leash/NN
#   let/VBD
#   slip/JJ
#   cominius/NN
#   slave/VBP
#   told/VBN
#   beat/NN
#   trenches/NNS
#   call/VBP
#   hither/RB
#   marcius/JJ
#   let/VB
#   alone/JJ
#   inform/VB
#   truth/JJ
#   gentlemen/NNS
#   common/JJ
#   file/NN
#   plague/NN
#   tribunes/NNS
#   mouse/VBP
#   shunn/JJ
#   cat/NN
#   budge/NN
#   rascals/NNS
#   worse/JJR
#   cominius/NN
#   prevail/IN
#   marcius/NN
#   time/NN
#   serve/VBP
#   tell/NN
#   think/VBP
#   enemy/NN
#   lords/NNS
#   field/NN
#   cease/NN
#   till/JJ
#   cominius/NN
#   marcius/NN
#   disadvantage/NN
#   fought/VBD
#   retire/NN
#   win/NN
#   purpose/JJ
#   marcius/NN
#   lies/VBZ
#   battle/NN
#   know/JJ
#   side/NN
#   placed/VBD
#   men/NNS
#   trust/VB
#   cominius/NN
#   guess/NN
#   marcius/NN
#   bands/VBZ
#   vaward/JJ
#   antiates/NNS
#   best/RB
#   trust/VBP
#   aufidius/JJ
#   heart/NN
#   hope/NN
#   marcius/NN
#   beseech/NN
#   battles/VBZ
#   wherein/RB
#   fought/JJ
#   blood/NN
#   shed/VBN
#   together/RB
#   vows/NNS
#   made/VBD
#   endure/NN
#   friends/NNS
#   directly/RB
#   set/VBN
#   aufidius/NN
#   antiates/NNS
#   delay/VBP
#   present/JJ
#   filling/VBG
#   air/NN
#   swords/NNS
#   advanced/VBD
#   darts/NNS
#   prove/VB
#   hour/NN
#   cominius/NN
#   though/IN
#   could/MD
#   wish/VB
#   conducted/VBN
#   gentle/JJ
#   bath/NN
#   balms/NNS
#   applied/VBN
#   yet/RB
#   dare/JJ
#   never/RB
#   deny/VBP
#   asking/VBG
#   take/NN
#   choice/NN
#   best/RBS
#   aid/NN
#   action/NN
#   marcius/NN
#   willing/JJ
#   sin/NN
#   doubt/NN
#   love/IN
#   painting/VBG
#   wherein/NN
#   see/VBP
#   smear/JJ
#   fear/VBP
#   lesser/JJR
#   person/NN
#   ill/JJ
#   report/NN
#   think/VBP
#   brave/VBP
#   death/NN
#   outweighs/NNS
#   bad/JJ
#   life/NN
#   country/NN
#   dearer/VBD
#   let/VB
#   alone/RB
#   many/JJ
#   minded/VBN
#   wave/VBP
#   thus/RB
#   express/JJ
#   disposition/NN
#   follow/JJ
#   marcius/NN
#   alone/RB
#   make/VB
#   sword/NN
#   shows/VBZ
#   outward/RB
#   four/CD
#   volsces/NNS
#   none/RB
#   able/JJ
#   bear/JJ
#   great/JJ
#   aufidius/JJ
#   shield/VBN
#   hard/RB
#   certain/JJ
#   number/NN
#   though/IN
#   thanks/NNS
#   must/MD
#   select/VB
#   rest/VB
#   shall/MD
#   bear/VB
#   business/NN
#   fight/NN
#   cause/NN
#   obey/JJ
#   please/NN
#   march/VB
#   four/CD
#   shall/MD
#   quickly/RB
#   draw/VB
#   command/NN
#   men/NNS
#   best/RB
#   inclined/JJ
#   cominius/NN
#   march/NN
#   fellows/NNS
#   make/VBP
#   good/JJ
#   ostentation/NN
#   shall/MD
#   divide/VB
#   us/PRP
#   lartius/JJ
#   let/VB
#   ports/NNS
#   guarded/VBN
#   keep/JJ
#   duties/NNS
#   set/VBD
#   send/JJ
#   dispatch/NN
#   centuries/NNS
#   aid/VBP
#   rest/NN
#   serve/NN
#   short/JJ
#   holding/VBG
#   lose/JJ
#   field/NN
#   keep/VB
#   town/NN
#   lieutenant/JJ
#   fear/NN
#   care/NN
#   sir/NN
#   lartius/NN
#   hence/NN
#   shut/NN
#   gates/VBZ
#   upon/IN
#   guider/NN
#   come/VBN
#   roman/NN
#   camp/NN
#   conduct/VBP
#   us/PRP
#   marcius/JJ
#   fight/VBD
#   none/NN
#   thee/NN
#   hate/NN
#   thee/NN
#   worse/JJR
#   aufidius/JJ
#   hate/NN
#   alike/IN
#   afric/JJ
#   owns/VBZ
#   serpent/JJ
#   abhor/NN
#   thy/JJ
#   fame/NN
#   envy/NN
#   fix/NN
#   thy/JJ
#   foot/NN
#   marcius/NN
#   let/VBD
#   first/JJ
#   budger/NN
#   die/NN
#   slave/VBP
#   gods/NNS
#   doom/NN
#   aufidius/VBP
#   fly/JJ
#   marcius/RB
#   holloa/VBP
#   like/IN
#   hare/NN
#   marcius/NN
#   within/IN
#   three/CD
#   hours/NNS
#   tullus/CC
#   alone/RB
#   fought/JJ
#   corioli/NN
#   walls/NNS
#   made/VBN
#   work/NN
#   pleased/JJ
#   blood/NN
#   wherein/NN
#   thou/VBD
#   seest/JJS
#   mask/NN
#   thy/JJ
#   revenge/NN
#   wrench/NN
#   thy/JJ
#   power/NN
#   highest/JJS
#   aufidius/NN
#   wert/NN
#   thou/NN
#   hector/NN
#   whip/NN
#   bragg/NN
#   progeny/NN
#   thou/NN
#   shouldst/NN
#   scape/NN
#   officious/JJ
#   valiant/NN
#   shamed/VBD
#   condemned/JJ
#   seconds/NNS
#   cominius/VBP
#   tell/VB
#   thee/JJ
#   thy/JJ
#   day/NN
#   work/NN
#   believe/VBP
#   thy/JJ
#   deeds/NNS
#   report/NN
#   senators/NNS
#   shall/MD
#   mingle/VB
#   tears/NNS
#   smiles/VBZ
#   great/JJ
#   patricians/NNS
#   shall/MD
#   attend/VB
#   shrug/JJ
#   end/NN
#   admire/NN
#   ladies/VBZ
#   shall/MD
#   frighted/VBN
#   gladly/RB
#   quaked/JJ
#   hear/JJ
#   dull/JJ
#   tribunes/NNS
#   fusty/JJ
#   plebeians/NNS
#   hate/VBP
#   thine/NN
#   honours/NN
#   shall/MD
#   say/VB
#   hearts/NNS
#   thank/VB
#   gods/NNS
#   rome/VB
#   hath/NN
#   soldier/NN
#   yet/RB
#   camest/JJS
#   thou/JJ
#   morsel/NN
#   feast/NN
#   fully/RB
#   dined/VBN
#   lartius/JJ
#   general/JJ
#   steed/NN
#   caparison/NN
#   hadst/NN
#   thou/JJ
#   beheld/NN
#   marcius/NN
#   pray/NN
#   mother/NN
#   charter/NN
#   extol/VBP
#   blood/NN
#   praise/NN
#   grieves/VBZ
#   done/VBN
#   done/VBN
#   induced/JJ
#   country/NN
#   effected/VBD
#   good/JJ
#   hath/NN
#   mine/NN
#   act/NN
#   cominius/VBP
#   shall/MD
#   grave/VB
#   deserving/VBG
#   rome/JJ
#   must/MD
#   know/VB
#   value/NN
#   concealment/JJ
#   worse/JJR
#   theft/NN
#   less/RBR
#   traducement/JJ
#   hide/NN
#   doings/NNS
#   silence/NN
#   spire/NN
#   top/JJ
#   praises/NNS
#   vouch/RB
#   would/MD
#   seem/VB
#   modest/JJ
#   therefore/RB
#   beseech/JJ
#   sign/NN
#   reward/NN
#   done/VBN
#   army/NN
#   hear/NN
#   marcius/NN
#   wounds/VBZ
#   upon/IN
#   smart/JJ
#   hear/JJ
#   remember/NN
#   cominius/NNS
#   well/RB
#   might/MD
#   fester/VB
#   ingratitude/JJ
#   tent/JJ
#   death/NN
#   horses/NNS
#   whereof/VBP
#   good/JJ
#   good/JJ
#   store/NN
#   treasure/NN
#   field/NN
#   achieved/VBD
#   city/NN
#   render/NN
#   tenth/JJ
#   forth/NN
#   common/JJ
#   distribution/NN
#   choice/NN
#   marcius/NN
#   thank/NN
#   general/JJ
#   make/VBP
#   heart/NN
#   consent/NN
#   take/VB
#   bribe/JJ
#   pay/NN
#   sword/NN
#   refuse/NN
#   stand/VBP
#   upon/IN
#   common/JJ
#   part/NN
#   beheld/NN
#   marcius/NN
#   may/MD
#   instruments/NNS
#   profane/VB
#   never/RB
#   sound/VBN
#   drums/JJ
#   trumpets/NNS
#   shall/MD
#   field/NN
#   prove/VB
#   flatterers/NNS
#   let/VB
#   courts/NNS
#   cities/NNS
#   made/VBN
#   soothing/VBG
#   steel/NN
#   grows/NNS
#   soft/JJ
#   parasite/JJ
#   silk/NN
#   let/NN
#   made/VBN
#   coverture/NN
#   wars/NNS
#   say/VBP
#   nose/RB
#   bled/VBN
#   foil/NN
#   debile/NN
#   without/IN
#   note/NN
#   many/JJ
#   else/RB
#   done/VBN
#   shout/NN
#   forth/NN
#   acclamations/NNS
#   hyperbolical/JJ
#   loved/VBD
#   little/JJ
#   dieted/JJ
#   praises/NNS
#   sauced/VBD
#   lies/NNS
#   cominius/VBP
#   modest/JJ
#   cruel/NN
#   good/JJ
#   report/NN
#   grateful/VBD
#   us/PRP
#   give/VB
#   truly/RB
#   patience/NN
#   incensed/VBD
#   put/VBN
#   like/IN
#   one/CD
#   means/VBZ
#   proper/JJ
#   harm/NN
#   manacles/NNS
#   reason/NN
#   safely/RB
#   therefore/RB
#   known/VBN
#   us/PRP
#   world/NN
#   caius/NN
#   marcius/JJ
#   wears/NNS
#   war/NN
#   garland/VBP
#   token/VBN
#   noble/JJ
#   steed/NN
#   known/VBN
#   camp/JJ
#   give/JJ
#   trim/NN
#   belonging/NN
#   time/NN
#   corioli/VB
#   call/NN
#   applause/IN
#   clamour/NN
#   host/NN
#   caius/NN
#   marcius/NN
#   coriolanus/NN
#   bear/IN
#   addition/NN
#   nobly/RB
#   ever/RB
#   caius/JJ
#   marcius/NN
#   coriolanus/NN
#   coriolanus/NN
#   go/VBP
#   wash/JJ
#   face/NN
#   fair/JJ
#   shall/MD
#   perceive/VB
#   whether/IN
#   blush/NN
#   howbeit/NN
#   thank/NN
#   mean/JJ
#   stride/NN
#   steed/VBD
#   times/NNS
#   undercrest/RB
#   good/JJ
#   addition/NN
#   fairness/NN
#   power/NN
#   cominius/NN
#   tent/NN
#   ere/RB
#   repose/VB
#   us/PRP
#   write/JJ
#   rome/JJ
#   success/NN
#   titus/NN
#   lartius/NN
#   must/MD
#   corioli/VB
#   back/RB
#   send/VB
#   us/PRP
#   rome/VB
#   best/JJS
#   may/MD
#   articulate/VB
#   good/JJ
#   lartius/NN
#   shall/MD
#   lord/VB
#   coriolanus/NN
#   gods/NNS
#   begin/VBP
#   mock/RB
#   refused/VBN
#   princely/RB
#   gifts/JJ
#   bound/NN
#   beg/NN
#   lord/NN
#   general/JJ
#   cominius/NN
#   coriolanus/NN
#   sometime/RB
#   lay/VBD
#   corioli/JJ
#   poor/JJ
#   man/NN
#   house/NN
#   used/VBN
#   kindly/RB
#   cried/JJ
#   saw/VBD
#   prisoner/NN
#   aufidius/NN
#   within/IN
#   view/NN
#   wrath/NN
#   pity/NN
#   request/VBP
#   give/JJ
#   poor/JJ
#   host/NN
#   freedom/NN
#   cominius/NN
#   well/RB
#   begg/IN
#   butcher/JJR
#   son/NN
#   free/JJ
#   wind/NN
#   deliver/NN
#   titus/NN
#   lartius/VBZ
#   marcius/JJ
#   name/NN
#   coriolanus/NN
#   jupiter/NN
#   forgot/VBD
#   weary/JJ
#   yea/NN
#   memory/NN
#   tired/JJ
#   wine/NN
#   cominius/NN
#   go/VBP
#   tent/JJ
#   blood/NN
#   upon/IN
#   visage/NN
#   dries/NNS
#   time/NN
#   look/VBP
#   come/JJ
#   aufidius/NN
#   town/NN
#   first/RB
#   soldier/VBD
#   deliver/VB
#   back/RB
#   good/JJ
#   condition/NN
#   aufidius/IN
#   condition/NN
#   would/MD
#   roman/VB
#   volsce/JJ
#   condition/NN
#   good/JJ
#   condition/NN
#   treaty/NN
#   find/VBP
#   part/NN
#   mercy/NN
#   five/CD
#   times/NNS
#   marcius/JJ
#   fought/JJ
#   thee/NN
#   often/RB
#   hast/JJ
#   thou/JJ
#   beat/NN
#   wouldst/NN
#   think/VBP
#   encounter/RBR
#   often/RB
#   eat/JJ
#   elements/NNS
#   meet/VB
#   beard/RB
#   beard/NN
#   mine/NN
#   mine/NN
#   emulation/NN
#   hath/IN
#   honour/NN
#   thought/VBD
#   crush/JJ
#   equal/JJ
#   force/NN
#   true/JJ
#   sword/NN
#   sword/NN
#   potch/NN
#   way/NN
#   wrath/IN
#   craft/NN
#   may/MD
#   get/VB
#   first/RB
#   soldier/JJR
#   devil/JJ
#   aufidius/NN
#   bolder/NN
#   though/IN
#   subtle/JJ
#   valour/NN
#   suffering/VBG
#   stain/VB
#   shall/MD
#   fly/VB
#   sleep/JJ
#   sanctuary/NN
#   naked/VBD
#   sick/JJ
#   fane/NN
#   capitol/NN
#   prayers/NNS
#   priests/VBZ
#   times/NNS
#   sacrifice/JJ
#   embarquements/NNS
#   fury/VBP
#   shall/MD
#   lift/VB
#   rotten/JJ
#   privilege/NN
#   custom/NN
#   hate/NN
#   marcius/NN
#   find/VBP
#   home/NN
#   upon/IN
#   brother/NN
#   guard/NN
#   even/RB
#   hospitable/JJ
#   canon/NN
#   would/MD
#   wash/VB
#   fierce/JJ
#   hand/NN
#   heart/NN
#   go/VBP
#   city/NN
#   learn/VBP
#   held/VBN
#   must/MD
#   hostages/VB
#   rome/VB
#   first/RB
#   soldier/JJR
#   go/VB
#   aufidius/RB
#   attended/JJ
#   cypress/NN
#   grove/NN
#   pray/NN
#   south/JJ
#   city/NN
#   mills/NNS
#   bring/VBP
#   word/NN
#   thither/NN
#   world/NN
#   goes/VBZ
#   pace/NN
#   may/MD
#   spur/VB
#   journey/NN
#   first/RB
#   soldier/JJR
#   shall/MD
#   sir/VB
#   menenius/JJ
#   augurer/NN
#   tells/NNS
#   shall/MD
#   news/NN
#   brutus/VB
#   good/JJ
#   bad/JJ
#   menenius/NN
#   according/VBG
#   prayer/NN
#   people/NNS
#   love/VBP
#   marcius/JJ
#   sicinius/JJ
#   nature/NN
#   teaches/VBZ
#   beasts/NNS
#   know/VBP
#   friends/VBZ
#   menenius/JJ
#   pray/NN
#   wolf/NN
#   love/VBP
#   sicinius/NN
#   lamb/NN
#   menenius/NN
#   ay/IN
#   devour/JJ
#   hungry/JJ
#   plebeians/NNS
#   would/MD
#   noble/JJ
#   marcius/NN
#   brutus/NN
#   lamb/VBP
#   indeed/RB
#   baes/VBP
#   like/IN
#   bear/JJ
#   menenius/FW
#   bear/VBP
#   indeed/RB
#   lives/NNS
#   like/IN
#   lamb/NN
#   two/CD
#   old/JJ
#   men/NNS
#   tell/VBP
#   one/CD
#   thing/NN
#   shall/MD
#   ask/VB
#   well/RB
#   sir/JJ
#   menenius/NN
#   enormity/NN
#   marcius/VBP
#   poor/JJ
#   two/CD
#   abundance/NN
#   brutus/NN
#   poor/JJ
#   one/CD
#   fault/NN
#   stored/VBD
#   sicinius/JJ
#   especially/RB
#   pride/JJ
#   brutus/NN
#   topping/VBG
#   others/NNS
#   boasting/VBG
#   menenius/JJ
#   strange/JJ
#   two/CD
#   know/VBP
#   censured/VBN
#   city/NN
#   mean/VBP
#   us/PRP
#   file/NN
#   censured/VBD
#   menenius/JJ
#   talk/NN
#   pride/NN
#   angry/JJ
#   well/RB
#   well/RB
#   sir/RB
#   well/RB
#   menenius/RB
#   great/JJ
#   matter/NN
#   little/JJ
#   thief/JJ
#   occasion/NN
#   rob/NN
#   great/JJ
#   deal/NN
#   patience/NN
#   give/VBP
#   dispositions/NNS
#   reins/NNS
#   angry/JJ
#   pleasures/NNS
#   least/JJS
#   take/VB
#   pleasure/NN
#   blame/NN
#   marcius/JJ
#   proud/JJ
#   brutus/NN
#   alone/RB
#   sir/JJ
#   menenius/NNS
#   know/VBP
#   little/JJ
#   alone/RB
#   helps/VBZ
#   many/JJ
#   else/JJ
#   actions/NNS
#   would/MD
#   grow/VB
#   wondrous/JJ
#   single/JJ
#   abilities/NNS
#   much/RB
#   alone/RB
#   talk/NN
#   pride/NN
#   could/MD
#   turn/VB
#   eyes/NNS
#   toward/IN
#   napes/NNS
#   necks/NNS
#   make/VBP
#   interior/JJ
#   survey/NN
#   good/JJ
#   selves/NNS
#   could/MD
#   brutus/VB
#   sir/JJ
#   menenius/NN
#   discover/NN
#   brace/NN
#   unmeriting/VBG
#   proud/JJ
#   violent/NN
#   testy/NN
#   magistrates/NNS
#   alias/VBP
#   fools/JJ
#   rome/JJ
#   sicinius/NN
#   menenius/NN
#   known/VBN
#   well/RB
#   enough/JJ
#   menenius/NN
#   known/VBN
#   humorous/JJ
#   patrician/JJ
#   one/CD
#   loves/VBZ
#   cup/NN
#   hot/JJ
#   wine/JJ
#   drop/NN
#   allaying/VBG
#   tiber/NNP
#   said/VBD
#   something/NN
#   imperfect/NN
#   favouring/VBG
#   first/JJ
#   complaint/NN
#   hasty/NN
#   upon/IN
#   trivial/JJ
#   motion/NN
#   one/CD
#   converses/VBZ
#   buttock/NN
#   night/NN
#   forehead/VBP
#   morning/NN
#   think/VBP
#   utter/JJ
#   spend/VBP
#   malice/JJ
#   breath/NN
#   meeting/NN
#   two/CD
#   wealsmen/NNS
#   call/VBP
#   lycurguses/VBZ
#   drink/VBP
#   give/VB
#   touch/JJ
#   palate/NN
#   adversely/RB
#   make/VBP
#   crooked/JJ
#   face/NN
#   ca/MD
#   say/VB
#   worships/NNS
#   delivered/VBN
#   matter/RB
#   well/RB
#   find/VB
#   ass/NN
#   compound/NN
#   major/JJ
#   part/NN
#   syllables/VBZ
#   though/IN
#   must/MD
#   content/VB
#   bear/IN
#   say/JJ
#   reverend/VBP
#   grave/VBP
#   men/NNS
#   yet/RB
#   lie/VBP
#   deadly/RB
#   tell/RB
#   good/JJ
#   faces/VBZ
#   see/VBP
#   map/JJ
#   microcosm/NN
#   follows/VBZ
#   known/VBN
#   well/RB
#   enough/RB
#   barm/JJ
#   bisson/NN
#   conspectuities/NNS
#   glean/VBP
#   character/NN
#   known/VBN
#   well/RB
#   enough/RB
#   brutus/JJ
#   come/VB
#   sir/JJ
#   come/VBN
#   know/VBP
#   well/RB
#   enough/RB
#   menenius/NN
#   know/VBP
#   neither/DT
#   thing/NN
#   ambitious/JJ
#   poor/JJ
#   knaves/NNS
#   caps/VBP
#   legs/JJ
#   wear/VBP
#   good/JJ
#   wholesome/NN
#   forenoon/NN
#   hearing/NN
#   cause/NN
#   orange/NN
#   wife/NN
#   rejourn/NN
#   controversy/NN
#   three/CD
#   pence/NN
#   second/JJ
#   day/NN
#   audience/NN
#   hearing/VBG
#   matter/NNP
#   party/NN
#   party/NN
#   chance/NN
#   pinched/VBD
#   colic/JJ
#   make/VBP
#   faces/VBZ
#   like/IN
#   mummers/NNS
#   set/VBP
#   bloody/JJ
#   flag/JJ
#   patience/NN
#   roaring/VBG
#   dismiss/JJ
#   controversy/NN
#   bleeding/VBG
#   entangled/VBD
#   hearing/VBG
#   peace/NN
#   make/VBP
#   cause/NN
#   calling/VBG
#   parties/NNS
#   knaves/VBZ
#   pair/JJ
#   strange/JJ
#   ones/NNS
#   brutus/RB
#   come/VBP
#   come/VBN
#   well/RB
#   understood/JJ
#   perfecter/NN
#   giber/NN
#   table/JJ
#   necessary/JJ
#   bencher/NN
#   capitol/NN
#   menenius/NN
#   priests/NNS
#   must/MD
#   become/VB
#   mockers/NNS
#   shall/MD
#   encounter/RB
#   ridiculous/JJ
#   subjects/NNS
#   speak/VBP
#   best/JJS
#   unto/JJ
#   purpose/NN
#   worth/IN
#   wagging/VBG
#   beards/NNS
#   beards/NNS
#   deserve/VBP
#   honourable/JJ
#   grave/NN
#   stuff/NN
#   cushion/NN
#   entombed/VBD
#   ass/NN
#   saddle/NN
#   yet/RB
#   must/MD
#   saying/VBG
#   marcius/VB
#   proud/JJ
#   cheap/JJ
#   estimation/NN
#   worth/IN
#   predecessors/NNS
#   since/IN
#   deucalion/NN
#   though/IN
#   peradventure/NN
#   best/JJS
#   hereditary/JJ
#   hangmen/NNS
#   worships/NNS
#   conversation/NN
#   would/MD
#   infect/VB
#   brain/NN
#   herdsmen/NNS
#   beastly/RB
#   plebeians/VBZ
#   bold/JJ
#   take/NN
#   leave/VBP
#   fair/VBN
#   noble/JJ
#   ladies/NNS
#   moon/VBP
#   earthly/RB
#   nobler/RB
#   whither/RB
#   follow/JJ
#   eyes/NNS
#   fast/RB
#   volumnia/VBP
#   honourable/JJ
#   menenius/NN
#   boy/NN
#   marcius/NN
#   approaches/NNS
#   love/VBP
#   juno/NN
#   let/NN
#   go/VB
#   menenius/JJ
#   ha/NN
#   marcius/NN
#   coming/VBG
#   home/RB
#   volumnia/NN
#   ay/NN
#   worthy/JJ
#   menenius/RB
#   prosperous/JJ
#   approbation/NN
#   menenius/NNS
#   take/VBP
#   cap/NN
#   jupiter/NN
#   thank/NN
#   thee/NN
#   hoo/NN
#   marcius/NN
#   coming/VBG
#   home/RB
#   volumnia/NN
#   nay/JJ
#   true/JJ
#   volumnia/NN
#   look/NN
#   letter/NN
#   state/NN
#   hath/NN
#   another/DT
#   wife/NN
#   another/DT
#   think/VBP
#   one/CD
#   home/NN
#   menenius/NNS
#   make/VBP
#   house/NN
#   reel/NN
#   tonight/JJ
#   letter/NN
#   virgilia/FW
#   yes/UH
#   certain/JJ
#   letter/NN
#   menenius/NN
#   letter/NN
#   gives/VBZ
#   estate/NN
#   seven/CD
#   years/NNS
#   health/NN
#   time/NN
#   make/VBP
#   lip/NN
#   physician/JJ
#   sovereign/NN
#   prescription/NN
#   galen/VBN
#   empiricutic/JJ
#   preservative/JJ
#   better/JJR
#   report/NN
#   wounded/VBD
#   wont/JJ
#   come/JJ
#   home/NN
#   wounded/VBD
#   virgilia/JJ
#   volumnia/NN
#   wounded/VBD
#   thank/JJ
#   gods/NNS
#   menenius/RB
#   much/JJ
#   brings/NNS
#   victory/NN
#   pocket/NN
#   wounds/VBZ
#   become/VBN
#   volumnia/JJ
#   brows/NNS
#   menenius/VBP
#   comes/VBZ
#   third/JJ
#   time/NN
#   home/NN
#   oaken/NN
#   garland/NN
#   menenius/NN
#   disciplined/VBD
#   aufidius/RB
#   soundly/RB
#   volumnia/JJ
#   titus/NN
#   lartius/NN
#   writes/VBZ
#   fought/VBN
#   together/RB
#   aufidius/JJ
#   got/VBD
#   menenius/JJ
#   time/NN
#   warrant/JJ
#   stayed/VBN
#   would/MD
#   fidiused/VBN
#   chests/NNS
#   corioli/VBP
#   gold/NN
#   senate/NN
#   possessed/VBN
#   volumnia/RB
#   good/JJ
#   ladies/NNS
#   let/VBP
#   go/VB
#   yes/UH
#   yes/RB
#   yes/RB
#   senate/JJ
#   letters/NNS
#   general/JJ
#   wherein/VBP
#   gives/VBZ
#   son/JJ
#   whole/JJ
#   name/NN
#   war/NN
#   hath/NN
#   action/NN
#   outdone/CD
#   former/JJ
#   deeds/NNS
#   doubly/RB
#   valeria/VBP
#   troth/RB
#   wondrous/JJ
#   things/NNS
#   spoke/VBD
#   menenius/RB
#   wondrous/JJ
#   ay/NN
#   warrant/NN
#   without/IN
#   true/JJ
#   purchasing/NN
#   virgilia/NNS
#   gods/NNS
#   grant/VBP
#   true/JJ
#   volumnia/NN
#   true/JJ
#   pow/NN
#   wow/JJ
#   menenius/NN
#   true/JJ
#   sworn/VBN
#   true/JJ
#   wounded/VBD
#   god/NN
#   save/VB
#   good/JJ
#   worships/NNS
#   marcius/VBP
#   coming/VBG
#   home/NN
#   cause/NN
#   proud/NN
#   wounded/VBD
#   volumnia/NN
#   shoulder/NN
#   left/VBD
#   arm/JJ
#   large/JJ
#   cicatrices/NNS
#   show/VBP
#   people/NNS
#   shall/MD
#   stand/VB
#   place/NN
#   received/VBN
#   repulse/JJ
#   tarquin/NN
#   seven/CD
#   hurts/NNS
#   body/NN
#   menenius/VBP
#   one/CD
#   neck/NN
#   two/CD
#   thigh/JJ
#   nine/CD
#   know/VBP
#   volumnia/VBN
#   last/JJ
#   expedition/NN
#   wounds/NNS
#   upon/IN
#   menenius/NN
#   every/DT
#   gash/NN
#   enemy/NN
#   grave/VBP
#   hark/VBN
#   trumpets/NNS
#   volumnia/VBP
#   ushers/NNS
#   marcius/JJ
#   carries/VBZ
#   noise/NN
#   behind/IN
#   leaves/VBZ
#   tears/NNS
#   death/NN
#   dark/NN
#   spirit/NN
#   nervy/JJ
#   arm/NN
#   doth/NN
#   lie/NN
#   advanced/VBD
#   declines/NNS
#   men/NNS
#   die/VBP
#   herald/NN
#   know/VBP
#   rome/VB
#   alone/JJ
#   marcius/NN
#   fight/NN
#   within/IN
#   corioli/NN
#   gates/NNS
#   hath/VBP
#   fame/JJ
#   name/NN
#   caius/NN
#   marcius/FW
#   honour/NN
#   follows/VBZ
#   coriolanus/VBP
#   welcome/JJ
#   rome/NN
#   renowned/VBD
#   coriolanus/JJ
#   welcome/JJ
#   rome/NN
#   renowned/VBD
#   coriolanus/JJ
#   coriolanus/NN
#   offend/VBP
#   heart/NN
#   pray/NN
#   cominius/NN
#   look/NN
#   sir/VBZ
#   mother/RB
#   coriolanus/NN
#   know/VBP
#   petition/NN
#   gods/NNS
#   prosperity/NN
#   volumnia/NN
#   nay/RB
#   good/JJ
#   soldier/NN
#   gentle/JJ
#   marcius/NN
#   worthy/JJ
#   caius/NN
#   honour/PRP$
#   newly/RB
#   named/VBN
#   coriolanus/NN
#   must/MD
#   call/VB
#   thee/NN
#   thy/JJ
#   wife/NN
#   coriolanus/NN
#   gracious/JJ
#   silence/NN
#   hail/NN
#   wouldst/NN
#   thou/NN
#   laugh/IN
#   come/JJ
#   coffin/NN
#   home/NN
#   see/VBP
#   triumph/JJ
#   ay/NN
#   dear/JJ
#   eyes/NNS
#   widows/VBZ
#   corioli/VBP
#   wear/JJ
#   mothers/NNS
#   lack/VBP
#   sons/NNS
#   menenius/VBP
#   gods/NNS
#   crown/JJ
#   thee/JJ
#   coriolanus/NN
#   live/JJ
#   yet/RB
#   sweet/JJ
#   lady/NN
#   pardon/NN
#   volumnia/NN
#   know/VBP
#   turn/VBP
#   welcome/JJ
#   home/NN
#   welcome/NN
#   general/JJ
#   ye/CC
#   welcome/JJ
#   menenius/NN
#   hundred/VBD
#   thousand/CD
#   welcomes/NNS
#   could/MD
#   weep/VB
#   could/MD
#   laugh/VB
#   light/JJ
#   heavy/JJ
#   welcome/JJ
#   curse/NN
#   begin/NN
#   root/VBP
#   heart/NN
#   glad/NN
#   see/VBP
#   thee/JJ
#   three/CD
#   rome/JJ
#   dote/NN
#   yet/RB
#   faith/VBN
#   men/NNS
#   old/JJ
#   home/NN
#   grafted/VBD
#   relish/JJ
#   yet/RB
#   welcome/JJ
#   warriors/NNS
#   call/VBP
#   nettle/JJ
#   nettle/JJ
#   faults/NNS
#   fools/NNS
#   folly/RB
#   cominius/VBP
#   ever/RB
#   right/RB
#   coriolanus/NN
#   menenius/NN
#   ever/RB
#   ever/RB
#   herald/VB
#   give/JJ
#   way/NN
#   go/VBP
#   coriolanus/NN
#   volumnia/NN
#   lived/VBD
#   see/NN
#   inherited/JJ
#   wishes/NNS
#   buildings/NNS
#   fancy/VBP
#   one/CD
#   thing/NN
#   wanting/VBG
#   doubt/NN
#   rome/VB
#   cast/NN
#   upon/IN
#   thee/JJ
#   coriolanus/NN
#   know/VBP
#   good/JJ
#   mother/NN
#   rather/RB
#   servant/JJ
#   way/NN
#   sway/JJ
#   cominius/NN
#   capitol/NN
#   brutus/NN
#   tongues/NNS
#   speak/VBP
#   bleared/VBN
#   sights/NNS
#   spectacled/VBD
#   see/VBP
#   prattling/VBG
#   nurse/JJ
#   rapture/NN
#   lets/VBZ
#   baby/JJ
#   cry/NN
#   chats/NNS
#   kitchen/VBP
#   malkin/FW
#   pins/NNS
#   richest/VBP
#   lockram/NN
#   reechy/NN
#   neck/NN
#   clambering/VBG
#   walls/NNS
#   eye/NN
#   stalls/NNS
#   bulks/VBP
#   windows/VBZ
#   smother/JJR
#   leads/NNS
#   fill/VB
#   ridges/NNS
#   horsed/VBN
#   variable/JJ
#   complexions/NNS
#   agreeing/VBG
#   earnestness/NN
#   see/NN
#   flamens/JJ
#   press/NN
#   among/IN
#   popular/JJ
#   throngs/NNS
#   puff/VBP
#   win/JJ
#   vulgar/NN
#   station/NN
#   veil/FW
#   dames/NNS
#   commit/VBP
#   war/NN
#   white/JJ
#   damask/NN
#   cheeks/NN
#   wanton/NN
#   spoil/NN
#   phoebus/NN
#   burning/VBG
#   kisses/NNS
#   pother/RB
#   whatsoever/RB
#   god/JJ
#   leads/VBZ
#   slily/RB
#   crept/JJ
#   human/JJ
#   powers/NNS
#   gave/VBD
#   graceful/JJ
#   posture/NN
#   sicinius/NN
#   sudden/JJ
#   warrant/NN
#   consul/NN
#   brutus/JJ
#   office/NN
#   may/MD
#   power/NN
#   go/VB
#   sleep/JJ
#   sicinius/NN
#   temperately/RB
#   transport/JJ
#   honours/NNS
#   begin/VBP
#   end/VBP
#   lose/JJ
#   hath/NN
#   brutus/NN
#   comfort/NN
#   sicinius/VBD
#   doubt/NN
#   commoners/NNS
#   stand/VBP
#   upon/IN
#   ancient/JJ
#   malice/NN
#   forget/NN
#   least/JJS
#   cause/VB
#   new/JJ
#   honours/NNS
#   give/VBP
#   make/VB
#   little/JJ
#   question/NN
#   proud/NN
#   brutus/NN
#   heard/VBD
#   swear/JJ
#   stand/NN
#   consul/NN
#   never/RB
#   would/MD
#   appear/VB
#   put/VB
#   napless/JJ
#   vesture/NN
#   humility/NN
#   showing/VBG
#   manner/JJ
#   wounds/NNS
#   people/NNS
#   beg/VBP
#   stinking/VBG
#   breaths/NNS
#   sicinius/RB
#   right/JJ
#   brutus/NN
#   word/NN
#   would/MD
#   miss/VB
#   rather/RB
#   carry/JJ
#   suit/NN
#   gentry/NN
#   desire/NN
#   nobles/NNS
#   sicinius/VBP
#   wish/JJ
# ...
#   wast/JJ
#   thou/NN
#   deservedly/RB
#   confined/VBD
#   rock/NN
#   hadst/NN
#   deserved/VBD
#   prison/JJ
#   caliban/NN
#   taught/JJ
#   language/NN
#   profit/NN
#   know/VBP
#   curse/NN
#   red/JJ
#   plague/NN
#   rid/JJ
#   learning/JJ
#   language/NN
#   prospero/NN
#   hence/NN
#   fetch/VBP
#   us/PRP
#   fuel/JJ
#   quick/JJ
#   best/JJS
#   answer/NN
#   business/NN
#   thou/NN
#   malice/NN
#   thou/NN
#   dost/NN
#   unwillingly/RB
#   command/VBP
#   rack/NN
#   thee/NN
#   old/JJ
#   cramps/NNS
#   fill/RB
#   thy/JJ
#   bones/NNS
#   aches/NNS
#   make/VBP
#   thee/JJ
#   roar/NN
#   beasts/NNS
#   shall/MD
#   tremble/VB
#   thy/JJ
#   din/JJ
#   caliban/NN
#   pray/NN
#   thee/NN
#   must/MD
#   obey/VB
#   art/NN
#   power/NN
#   would/MD
#   control/VB
#   dam/JJ
#   god/NN
#   setebos/NNS
#   make/VBP
#   vassal/NN
#   prospero/NN
#   slave/VBP
#   hence/NN
#   come/VBN
#   unto/RB
#   yellow/JJ
#   sands/NNS
#   take/VBP
#   hands/NNS
#   courtsied/VBN
#   wild/JJ
#   waves/NNS
#   whist/VBP
#   foot/NN
#   featly/RB
#   sweet/JJ
#   sprites/NNS
#   burthen/VBP
#   bear/JJ
#   hark/NN
#   hark/NN
#   ferdinand/NN
#   music/NN
#   air/NN
#   earth/JJ
#   sounds/VBZ
#   sure/JJ
#   waits/NNS
#   upon/IN
#   god/JJ
#   island/NN
#   sitting/VBG
#   bank/NN
#   weeping/VBG
#   king/VBG
#   father/NN
#   wreck/NN
#   music/NN
#   crept/NN
#   upon/IN
#   waters/NNS
#   allaying/VBG
#   fury/NN
#   passion/NN
#   sweet/VBD
#   air/NN
#   thence/NN
#   follow/VBP
#   hath/NN
#   drawn/NN
#   rather/RB
#   gone/VBN
#   begins/VBZ
#   full/JJ
#   fathom/NN
#   five/CD
#   thy/NN
#   father/NN
#   lies/VBZ
#   bones/NNS
#   coral/JJ
#   made/VBD
#   pearls/JJ
#   eyes/NNS
#   nothing/NN
#   doth/RB
#   fade/VBD
#   doth/DT
#   suffer/NN
#   something/NN
#   rich/JJ
#   strange/JJ
#   hourly/RB
#   ring/VBG
#   knell/NN
#   hark/NN
#   hear/VBP
#   bell/NN
#   ferdinand/NN
#   ditty/JJ
#   remember/VB
#   drown/JJ
#   father/NN
#   mortal/NN
#   business/NN
#   sound/VBD
#   earth/JJ
#   owes/JJ
#   hear/NN
#   prospero/NN
#   fringed/VBD
#   curtains/NNS
#   thine/VB
#   eye/NN
#   advance/NN
#   say/VBP
#   thou/JJ
#   seest/JJS
#   yond/NN
#   miranda/NN
#   spirit/NN
#   lord/NN
#   looks/VBZ
#   believe/VBP
#   sir/NN
#   carries/VBZ
#   brave/VBP
#   form/NN
#   spirit/NN
#   prospero/NN
#   wench/NN
#   eats/VBZ
#   sleeps/JJ
#   hath/NN
#   senses/NNS
#   gallant/JJ
#   thou/JJ
#   seest/JJS
#   wreck/NN
#   something/NN
#   grief/JJ
#   beauty/NN
#   canker/NN
#   thou/NN
#   mightst/NN
#   call/NN
#   goodly/RB
#   person/NN
#   hath/NN
#   lost/VBD
#   fellows/NNS
#   strays/NNS
#   find/VBP
#   miranda/JJ
#   might/MD
#   call/VB
#   thing/NN
#   divine/NN
#   nothing/NN
#   natural/JJ
#   ever/RB
#   saw/VBD
#   noble/JJ
#   prospero/NN
#   ferdinand/NN
#   sure/JJ
#   goddess/NN
#   airs/NNS
#   attend/VBP
#   vouchsafe/JJ
#   prayer/NN
#   may/MD
#   know/VB
#   remain/VB
#   upon/JJ
#   island/NN
#   good/JJ
#   instruction/NN
#   give/NN
#   may/MD
#   bear/VB
#   prime/JJ
#   request/NN
#   last/JJ
#   pronounce/NN
#   wonder/NN
#   maid/NN
#   miranda/NN
#   wonder/NN
#   sir/NN
#   certainly/RB
#   maid/VBD
#   ferdinand/JJ
#   language/NN
#   heavens/VBZ
#   best/RBS
#   speak/JJ
#   speech/NN
#   spoken/VBN
#   prospero/NN
#   best/JJS
#   wert/NN
#   thou/NN
#   king/VBG
#   naples/NNS
#   heard/RB
#   thee/VBP
#   ferdinand/VBP
#   single/JJ
#   thing/NN
#   wonders/NNS
#   hear/VBP
#   thee/JJ
#   speak/NN
#   naples/NNS
#   hear/VBP
#   weep/JJ
#   naples/NNS
#   mine/VB
#   eyes/NNS
#   never/RB
#   since/IN
#   ebb/JJ
#   beheld/NN
#   king/VBG
#   father/JJR
#   wreck/NN
#   miranda/NN
#   alack/NN
#   mercy/NN
#   ferdinand/VBP
#   yes/UH
#   faith/JJ
#   lords/NNS
#   duke/VBP
#   milan/NN
#   brave/VBP
#   son/NN
#   twain/NN
#   prospero/NN
#   miranda/NN
#   speaks/VBZ
#   father/RB
#   ungently/JJ
#   third/JJ
#   man/NN
#   saw/VBD
#   first/JJ
#   sigh/JJ
#   pity/NN
#   move/VBP
#   father/RB
#   inclined/JJ
#   way/NN
#   ferdinand/NN
#   virgin/NN
#   affection/NN
#   gone/VBN
#   forth/JJ
#   make/VBP
#   queen/JJ
#   naples/NNS
#   prospero/VBP
#   soft/JJ
#   sir/NN
#   one/CD
#   word/NN
#   either/CC
#   powers/NNS
#   swift/VBP
#   business/NN
#   must/MD
#   uneasy/VB
#   make/VB
#   lest/JJS
#   light/NN
#   winning/VBG
#   make/JJ
#   prize/NN
#   light/JJ
#   one/CD
#   word/NN
#   charge/NN
#   thee/NN
#   thou/JJ
#   attend/NN
#   thou/NN
#   dost/NN
#   usurp/JJ
#   name/NN
#   thou/NN
#   owest/JJS
#   hast/NN
#   put/VBD
#   thyself/PRP
#   upon/IN
#   island/NN
#   spy/NN
#   win/VBP
#   lord/NN
#   ferdinand/NN
#   man/NN
#   miranda/VBZ
#   nothing/NN
#   ill/NN
#   dwell/VBP
#   temple/NN
#   ill/NN
#   spirit/VBD
#   fair/JJ
#   house/NN
#   good/JJ
#   things/NNS
#   strive/VBP
#   dwell/NN
#   prospero/NN
#   follow/VBP
#   speak/NN
#   traitor/NN
#   come/VBP
#   manacle/NN
#   thy/JJ
#   neck/NN
#   feet/NNS
#   together/RB
#   shalt/VBP
#   thou/JJ
#   drink/NN
#   thy/NN
#   food/NN
#   shall/MD
#   muscles/VB
#   wither/JJR
#   roots/NNS
#   husks/NNS
#   wherein/VBP
#   acorn/JJ
#   cradled/VBN
#   follow/JJ
#   ferdinand/NN
#   resist/NN
#   entertainment/NN
#   till/NN
#   mine/NN
#   enemy/NN
#   power/NN
#   miranda/NN
#   dear/VBP
#   father/RB
#   make/VB
#   rash/JJ
#   trial/NN
#   gentle/NN
#   fearful/JJ
#   prospero/NNS
#   say/VBP
#   foot/JJ
#   tutor/NN
#   put/VBD
#   thy/JJ
#   sword/NN
#   traitor/NN
#   makest/JJS
#   show/NN
#   darest/JJS
#   strike/NN
#   thy/JJ
#   conscience/NN
#   possess/NN
#   guilt/VBD
#   come/JJ
#   thy/JJ
#   ward/NN
#   disarm/NN
#   thee/NN
#   stick/JJ
#   make/VBP
#   thy/JJ
#   weapon/IN
#   drop/NN
#   miranda/NN
#   beseech/NN
#   father/NN
#   prospero/NN
#   hence/NN
#   hang/NN
#   garments/NNS
#   miranda/VBP
#   sir/JJ
#   pity/NN
#   surety/NN
#   prospero/NN
#   silence/NN
#   one/CD
#   word/NN
#   shall/MD
#   make/VB
#   chide/NN
#   thee/NN
#   hate/NN
#   thee/NN
#   advocate/VBP
#   imposter/NN
#   hush/NN
#   thou/NN
#   shapes/NNS
#   seen/VBN
#   caliban/JJ
#   foolish/JJ
#   wench/NN
#   men/NNS
#   caliban/VBP
#   angels/NNS
#   miranda/VBP
#   affections/NNS
#   humble/JJ
#   ambition/NN
#   see/VBP
#   goodlier/JJR
#   man/NN
#   prospero/NN
#   come/VBP
#   obey/IN
#   thy/JJ
#   nerves/NNS
#   infancy/VBP
#   vigour/CD
#   ferdinand/NN
#   spirits/NNS
#   dream/VBP
#   bound/IN
#   father/JJR
#   loss/NN
#   weakness/NN
#   feel/VB
#   wreck/JJ
#   friends/NNS
#   man/NN
#   threats/VBZ
#   subdued/VBN
#   light/JJ
#   might/MD
#   prison/VB
#   day/NN
#   behold/VB
#   maid/NN
#   corners/NNS
#   else/RB
#   earth/VBP
#   let/VB
#   liberty/JJ
#   make/VB
#   use/JJ
#   space/NN
#   enough/JJ
#   prison/NN
#   prospero/NN
#   miranda/NN
#   comfort/NN
#   father/RB
#   better/RBR
#   nature/NN
#   sir/JJ
#   appears/VBZ
#   speech/NN
#   unwonted/JJ
#   came/VBD
#   prospero/JJ
#   thou/NN
#   shalt/VBD
#   free/JJ
#   mountain/NN
#   winds/NNS
#   exactly/RB
#   points/NNS
#   command/VBP
#   ariel/RB
#   syllable/JJ
#   prospero/NN
#   come/VBN
#   follow/JJ
#   speak/NN
#   gonzalo/NN
#   beseech/NN
#   sir/NN
#   merry/NN
#   cause/NN
#   joy/NN
#   escape/NN
#   much/JJ
#   beyond/IN
#   loss/NN
#   hint/NN
#   woe/NN
#   common/JJ
#   every/DT
#   day/NN
#   sailor/VBZ
#   wife/NN
#   masters/NNS
#   merchant/VBP
#   merchant/JJ
#   theme/NN
#   woe/NN
#   miracle/NN
#   mean/JJ
#   preservation/NN
#   millions/NNS
#   speak/VBP
#   like/IN
#   us/PRP
#   wisely/RB
#   good/JJ
#   sir/NN
#   weigh/JJ
#   sorrow/NN
#   comfort/NN
#   alonso/NN
#   prithee/NN
#   peace/NN
#   sebastian/JJ
#   receives/VBZ
#   comfort/NN
#   like/IN
#   cold/JJ
#   porridge/NN
#   antonio/NN
#   visitor/NN
#   give/VBP
#   sebastian/JJ
#   look/NN
#   winding/VBG
#   watch/NN
#   wit/NN
#   strike/NN
#   gonzalo/NN
#   sir/NN
#   sebastian/JJ
#   one/CD
#   tell/NN
#   gonzalo/NN
#   every/DT
#   grief/NN
#   entertain/NN
#   offer/NN
#   comes/VBZ
#   entertainer/JJ
#   sebastian/JJ
#   dollar/NN
#   gonzalo/VB
#   dolour/NN
#   comes/VBZ
#   indeed/RB
#   spoken/JJ
#   truer/NN
#   purposed/VBD
#   sebastian/JJ
#   taken/VBN
#   wiselier/NN
#   meant/JJ
#   gonzalo/NN
#   therefore/RB
#   lord/JJ
#   antonio/NN
#   fie/NN
#   spendthrift/NN
#   tongue/NN
#   alonso/NN
#   prithee/NN
#   spare/JJ
#   gonzalo/NN
#   well/RB
#   done/VBN
#   yet/RB
#   sebastian/JJ
#   talking/VBG
#   antonio/JJ
#   adrian/JJ
#   good/JJ
#   wager/NN
#   first/RB
#   begins/VBZ
#   crow/JJ
#   sebastian/JJ
#   old/JJ
#   cock/NN
#   antonio/NN
#   cockerel/NN
#   sebastian/JJ
#   done/VBN
#   wager/NN
#   antonio/NN
#   laughter/NN
#   sebastian/JJ
#   match/NN
#   adrian/JJ
#   though/IN
#   island/NN
#   seem/VBP
#   desert/NN
#   sebastian/JJ
#   ha/NN
#   ha/NN
#   ha/NN
#   paid/VBD
#   adrian/JJ
#   uninhabitable/JJ
#   almost/RB
#   inaccessible/JJ
#   sebastian/JJ
#   yet/RB
#   adrian/JJ
#   yet/RB
#   antonio/NN
#   could/MD
#   adrian/VB
#   must/MD
#   needs/VB
#   subtle/JJ
#   tender/NN
#   delicate/NN
#   temperance/NN
#   antonio/NN
#   temperance/NN
#   delicate/NN
#   wench/NN
#   sebastian/JJ
#   ay/NN
#   subtle/NN
#   learnedly/RB
#   delivered/VBD
#   adrian/JJ
#   air/NN
#   breathes/NNS
#   upon/IN
#   us/PRP
#   sweetly/RB
#   sebastian/JJ
#   lungs/NNS
#   rotten/VBP
#   ones/NNS
#   antonio/RB
#   perfumed/VBD
#   fen/JJ
#   gonzalo/NN
#   everything/NN
#   advantageous/JJ
#   life/NN
#   antonio/NN
#   true/JJ
#   save/NN
#   means/NNS
#   live/VBP
#   sebastian/JJ
#   none/NN
#   little/JJ
#   gonzalo/JJ
#   lush/NN
#   lusty/JJ
#   grass/NN
#   looks/VBZ
#   green/JJ
#   antonio/NN
#   ground/NN
#   indeed/RB
#   tawny/JJ
#   sebastian/JJ
#   eye/NN
#   green/JJ
#   antonio/NN
#   misses/NNS
#   much/JJ
#   sebastian/JJ
#   doth/NN
#   mistake/VBP
#   truth/NN
#   totally/RB
#   gonzalo/JJ
#   rarity/NN
#   indeed/RB
#   almost/RB
#   beyond/IN
#   credit/NN
#   sebastian/JJ
#   many/JJ
#   vouched/VBN
#   rarities/NNS
#   gonzalo/VBP
#   garments/NNS
#   drenched/VBD
#   sea/NN
#   hold/NN
#   notwithstanding/VBG
#   freshness/JJ
#   glosses/NNS
#   rather/RB
#   stained/VBD
#   salt/JJ
#   water/NN
#   antonio/VBD
#   one/CD
#   pockets/NNS
#   could/MD
#   speak/VB
#   would/MD
#   say/VB
#   lies/NNS
#   sebastian/JJ
#   ay/NN
#   falsely/RB
#   pocket/JJ
#   report/NN
#   gonzalo/VBD
#   methinks/NNS
#   garments/NNS
#   fresh/JJ
#   put/VBD
#   first/RB
#   afric/JJ
#   marriage/NN
#   king/VBG
#   fair/JJ
#   daughter/NN
#   claribel/NN
#   king/VBG
#   tunis/NN
#   sebastian/JJ
#   sweet/JJ
#   marriage/NN
#   prosper/NN
#   well/RB
#   return/VB
#   adrian/JJ
#   tunis/NN
#   never/RB
#   graced/VBD
#   paragon/NN
#   queen/NN
#   gonzalo/NN
#   since/IN
#   widow/NN
#   dido/NN
#   time/NN
#   antonio/JJ
#   widow/NN
#   pox/NN
#   came/VBD
#   widow/JJ
#   widow/NN
#   dido/NN
#   sebastian/NN
#   said/VBD
#   aeneas/RB
#   good/JJ
#   lord/NNS
#   take/VBP
#   adrian/JJ
#   dido/NN
#   said/VBD
#   make/NN
#   study/NN
#   carthage/NN
#   tunis/NN
#   gonzalo/NN
#   tunis/NN
#   sir/JJ
#   carthage/NN
#   adrian/JJ
#   carthage/NN
#   gonzalo/JJ
#   assure/NN
#   carthage/NN
#   sebastian/JJ
#   word/NN
#   miraculous/JJ
#   harp/NN
#   hath/NN
#   raised/VBD
#   wall/NN
#   houses/NNS
#   antonio/VBP
#   impossible/JJ
#   matter/NN
#   make/VBP
#   easy/JJ
#   next/JJ
#   sebastian/JJ
#   think/NN
#   carry/VBP
#   island/VBP
#   home/NN
#   pocket/NN
#   give/JJ
#   son/NN
#   apple/NN
#   antonio/NN
#   sowing/NN
#   kernels/NNS
#   sea/VBP
#   bring/VBG
#   forth/NN
#   islands/NNS
#   gonzalo/VBP
#   ay/JJ
#   antonio/RB
#   good/JJ
#   time/NN
#   gonzalo/NN
#   sir/NN
#   talking/VBG
#   garments/NNS
#   seem/VBP
#   fresh/JJ
#   tunis/NN
#   marriage/NN
#   daughter/NN
#   queen/JJ
#   antonio/JJ
#   rarest/NN
#   came/VBD
#   sebastian/JJ
#   bate/NN
#   beseech/NN
#   widow/NN
#   dido/NN
#   antonio/NN
#   widow/NN
#   dido/NN
#   ay/NN
#   widow/NN
#   dido/NN
#   gonzalo/NN
#   sir/JJ
#   doublet/NN
#   fresh/JJ
#   first/JJ
#   day/NN
#   wore/VBD
#   mean/JJ
#   sort/NN
#   antonio/NN
#   sort/NN
#   well/RB
#   fished/VBN
#   gonzalo/NN
#   wore/RBR
#   daughter/NN
#   marriage/NN
#   alonso/JJ
#   cram/NN
#   words/NNS
#   mine/VBP
#   ears/NNS
#   stomach/VBP
#   sense/NN
#   would/MD
#   never/RB
#   married/VBN
#   daughter/NN
#   coming/VBG
#   thence/NN
#   son/NN
#   lost/VBD
#   rate/NN
#   far/RB
#   italy/VBZ
#   removed/JJ
#   shall/MD
#   see/VB
#   thou/JJ
#   mine/VB
#   heir/NN
#   naples/NNS
#   milan/VBP
#   strange/JJ
#   fish/JJ
#   hath/NN
#   made/VBD
#   meal/JJ
#   thee/JJ
#   francisco/NN
#   sir/NN
#   may/MD
#   live/VB
#   saw/NN
#   beat/NN
#   surges/VBZ
#   ride/VBP
#   upon/IN
#   backs/NNS
#   trod/JJ
#   water/NN
#   whose/WP$
#   enmity/NN
#   flung/NN
#   aside/RB
#   breasted/VBD
#   surge/NN
#   swoln/NN
#   met/VBD
#   bold/JJ
#   head/NN
#   contentious/JJ
#   waves/NNS
#   kept/VBD
#   good/JJ
#   arms/NNS
#   lusty/JJ
#   stroke/VBD
#   shore/JJ
#   basis/NN
#   bow/NN
#   stooping/VBG
#   relieve/JJ
#   doubt/NN
#   came/VBD
#   alive/JJ
#   land/NN
#   alonso/VBZ
#   gone/VBN
#   sebastian/JJ
#   sir/NN
#   may/MD
#   thank/VB
#   great/JJ
#   loss/NN
#   would/MD
#   bless/VB
#   europe/VB
#   daughter/NN
#   rather/RB
#   lose/JJ
#   african/JJ
#   least/JJS
#   banish/JJ
#   eye/NN
#   hath/NN
#   cause/NN
#   wet/NN
#   grief/NN
#   alonso/JJ
#   prithee/NN
#   peace/NN
#   sebastian/JJ
#   kneel/NN
#   importuned/VBD
#   otherwise/RB
#   us/PRP
#   fair/JJ
#   soul/JJ
#   weigh/JJ
#   loathness/NN
#   obedience/NN
#   end/NN
#   beam/NN
#   bow/NN
#   lost/VBD
#   son/NN
#   fear/NN
#   ever/RB
#   milan/VBZ
#   naples/JJ
#   widows/NNS
#   business/NN
#   making/VBG
#   bring/VBG
#   men/NNS
#   comfort/NN
#   fault/NN
#   alonso/JJ
#   loss/NN
#   gonzalo/NN
#   lord/NN
#   sebastian/JJ
#   truth/NN
#   speak/NN
#   doth/DT
#   lack/NN
#   gentleness/NN
#   time/NN
#   speak/JJ
#   rub/NN
#   sore/NN
#   bring/NN
#   plaster/NN
#   sebastian/JJ
#   well/RB
#   antonio/IN
#   chirurgeonly/RB
#   gonzalo/JJ
#   foul/NN
#   weather/NN
#   us/PRP
#   good/JJ
#   sir/NN
#   cloudy/NN
#   sebastian/JJ
#   foul/NN
#   weather/NN
#   antonio/JJ
#   foul/NN
#   gonzalo/NN
#   plantation/NN
#   isle/NN
#   lord/NN
#   antonio/NN
#   sebastian/JJ
#   docks/NNS
#   mallows/VBZ
#   gonzalo/NN
#   king/VBG
#   would/MD
#   sebastian/VB
#   drunk/NN
#   want/VBP
#   wine/NN
#   gonzalo/NN
#   commonwealth/NN
#   would/MD
#   contraries/VB
#   execute/JJ
#   things/NNS
#   kind/NN
#   traffic/NN
#   would/MD
#   admit/VB
#   name/NN
#   magistrate/JJ
#   letters/NNS
#   known/VBN
#   riches/NNS
#   poverty/NN
#   use/NN
#   service/NN
#   none/NN
#   contract/NN
#   succession/NN
#   bourn/NN
#   bound/NN
#   land/NN
#   tilth/NN
#   vineyard/IN
#   none/NN
#   use/NN
#   metal/NN
#   corn/NN
#   wine/NN
#   oil/NN
#   occupation/NN
#   men/NNS
#   idle/JJ
#   women/NNS
#   innocent/JJ
#   pure/JJ
#   sovereignty/NN
#   sebastian/JJ
#   yet/RB
#   would/MD
#   king/VB
#   antonio/NN
#   latter/JJ
#   end/NN
#   commonwealth/NN
#   forgets/NNS
#   beginning/VBG
#   gonzalo/JJ
#   things/NNS
#   common/JJ
#   nature/NN
#   produce/NN
#   without/IN
#   sweat/NN
#   endeavour/VBP
#   treason/NN
#   felony/NN
#   sword/NN
#   pike/IN
#   knife/NN
#   gun/NNS
#   need/VBP
#   engine/NN
#   would/MD
#   nature/VB
#   bring/VB
#   forth/JJ
#   kind/NN
#   foison/NN
#   abundance/NN
#   feed/VBD
#   innocent/JJ
#   people/NNS
#   sebastian/JJ
#   marrying/VBG
#   subjects/NNS
#   antonio/VBP
#   none/NN
#   man/NN
#   idle/JJ
#   whores/VBZ
#   knaves/NNS
#   gonzalo/NNS
#   would/MD
#   perfection/VB
#   govern/JJ
#   sir/JJ
#   excel/NN
#   golden/JJ
#   age/NN
#   sebastian/JJ
#   god/NN
#   save/VBP
#   majesty/NNS
#   antonio/RB
#   long/RB
#   live/JJ
#   gonzalo/NN
#   gonzalo/NN
#   mark/NN
#   sir/NN
#   alonso/NN
#   prithee/NN
#   thou/NN
#   dost/NN
#   talk/NN
#   nothing/NN
#   gonzalo/NN
#   well/RB
#   believe/VB
#   highness/NN
#   minister/NN
#   occasion/NN
#   gentlemen/NNS
#   sensible/JJ
#   nimble/JJ
#   lungs/NNS
#   always/RB
#   use/VBP
#   laugh/JJ
#   nothing/NN
#   antonio/NN
#   laughed/VBD
#   gonzalo/JJ
#   kind/NN
#   merry/NN
#   fooling/VBG
#   nothing/NN
#   may/MD
#   continue/VB
#   laugh/IN
#   nothing/NN
#   still/RB
#   antonio/VBZ
#   blow/VB
#   given/VBN
#   sebastian/JJ
#   fallen/VBN
#   gonzalo/JJ
#   gentlemen/NNS
#   brave/VBP
#   metal/NN
#   would/MD
#   lift/VB
#   moon/NN
#   sphere/RB
#   would/MD
#   continue/VB
#   five/CD
#   weeks/NNS
#   without/IN
#   changing/VBG
#   sebastian/NN
#   would/MD
#   go/VB
#   antonio/JJ
#   nay/RB
#   good/JJ
#   lord/NN
#   angry/JJ
#   gonzalo/NN
#   warrant/NN
#   adventure/NN
#   discretion/NN
#   weakly/RB
#   laugh/IN
#   asleep/JJ
#   heavy/JJ
#   antonio/NN
#   go/VBP
#   sleep/JJ
#   hear/VBP
#   us/PRP
#   alonso/JJ
#   soon/RB
#   asleep/JJ
#   wish/JJ
#   mine/NN
#   eyes/NNS
#   would/MD
#   shut/VB
#   thoughts/NNS
#   find/VBP
#   inclined/JJ
#   sebastian/JJ
#   please/NN
#   sir/JJ
#   omit/NN
#   heavy/JJ
#   offer/NN
#   seldom/JJ
#   visits/NNS
#   sorrow/VBP
#   doth/JJ
#   comforter/NN
#   antonio/NN
#   two/CD
#   lord/NN
#   guard/NN
#   person/NN
#   take/VB
#   rest/NN
#   watch/NN
#   safety/NN
#   alonso/IN
#   thank/NN
#   wondrous/JJ
#   heavy/JJ
#   sebastian/JJ
#   strange/JJ
#   drowsiness/NN
#   possesses/NNS
#   antonio/VBP
#   quality/NN
#   climate/NN
#   sebastian/JJ
#   doth/NN
#   eyelids/NNS
#   sink/VBP
#   find/VBP
#   disposed/JJ
#   sleep/JJ
#   antonio/NN
#   spirits/NNS
#   nimble/JJ
#   fell/VBD
#   together/RB
#   consent/JJ
#   dropp/NN
#   might/MD
#   worthy/VB
#   sebastian/JJ
#   might/MD
#   yet/RB
#   thinks/VB
#   see/NN
#   thy/JJ
#   face/NN
#   thou/NN
#   shouldst/NN
#   occasion/NN
#   speaks/VBZ
#   thee/NN
#   strong/JJ
#   imagination/NN
#   sees/NNS
#   crown/VBP
#   dropping/VBG
#   upon/IN
#   thy/JJ
#   head/NN
#   sebastian/JJ
#   art/NN
#   thou/NN
#   waking/VBG
#   antonio/JJ
#   hear/JJ
#   speak/NN
#   sebastian/JJ
#   surely/RB
#   sleepy/JJ
#   language/NN
#   thou/NN
#   thy/JJ
#   sleep/JJ
#   thou/NN
#   didst/NNS
#   say/VBP
#   strange/JJ
#   repose/JJ
#   asleep/JJ
#   eyes/NNS
#   wide/JJ
#   open/JJ
#   standing/VBG
#   speaking/VBG
#   moving/VBG
#   yet/RB
#   fast/RB
#   asleep/JJ
#   antonio/NN
#   noble/JJ
#   sebastian/JJ
#   thou/NN
#   thy/JJ
#   fortune/NN
#   sleep/NN
#   die/NN
#   rather/RB
#   whiles/VBZ
#   thou/VB
#   art/NN
#   waking/VBG)

# %%
len(set(lemma))
# Out:
# 9603

# %% [markdown]
# **Web Scrapping**

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.nytimes.com/international/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
website_text = soup.get_text()
website_text = sent_tokenize(website_text)

# %%
print(website_text[0:10])
# Out:
# ['\n\n\n\nThe New York Times International - Breaking News, US News, World News, Videos\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to contentSkip to site indexSKIP ADVERTISEMENTSkip to contentSkip to site indexU.S.InternationalCanadaEspañol中文\xa0Today’s PaperU.S.SectionsU.S.PoliticsNew YorkCaliforniaEducationHealthObituariesScienceClimateSportsBusinessTechThe UpshotThe MagazineU.S.', 'Politics2024 ElectionsSupreme CourtCongressBiden AdministrationTop StoriesTrump InvestigationsImmigrationAbortionThe Eric Adams AdministrationNewslettersThe MorningMake sense of the day’s news and ideas.The UpshotAnalysis that explains politics, policy and everyday life.See all newslettersPodcastsThe DailyThe biggest stories of our time, in 20 minutes a day.The Run-UpOn the campaign trail with Astead Herndon.See all podcastsWorldSectionsWorldAfricaAmericasAsiaAustraliaCanadaEuropeMiddle EastScienceClimateHealthObituariesTop StoriesIsrael-Hamas WarRussia-Ukraine WarNewslettersMorning Briefing: EuropeGet what you need to know to start your day.The InterpreterOriginal analysis on the week’s biggest global stories.Australia LetterNews, features and opinion for readers in the region.Canada LetterBackstories and analysis from our Canadian correspondents.See all newslettersBusinessSectionsBusinessTechEconomyMediaFinance and MarketsDealBookPersonal TechEnergy TransitionYour MoneyTop StoriesU.S.', "EconomyStock MarketArtificial IntelligenceNewslettersDealBookThe most crucial business and policy news you need to know.See all newslettersPodcastsHard ForkOur tech journalists help you make sense of the rapidly changing tech world.See all podcastsArtsSectionsToday's ArtsBooksBest SellersDanceMoviesMusicTelevisionTheaterPop CultureT MagazineVisual ArtsRecommendationsBest of 2023Award SeasonCritic’s PicksWhat to ReadWhat to WatchWhat to Listen To5 Minutes to Make You Love MusicNewslettersRead Like the WindBook recommendations from our critics.WatchingStreaming TV and movie recommendations.See all newslettersPodcastsBook ReviewThe podcast that takes you inside the literary world.PopcastPop music news, new songs and albums, and artists of note.See all podcastsLifestyleSectionsLifestyleWellTravelStyleReal EstateFoodFashionLoveYour MoneyPersonal TechT MagazineColumnsModern LoveThe HuntSocial Q’sThe EthicistWellEatMoveMindFamilyLiveAsk WellNewslettersOpen ThreadThe latest news on what we wear, by our chief fashion critic.Love LetterReal stories of relationship highs, lows and woes.See all newslettersPodcastsModern LoveThe complicated love lives of real people.See all podcastsOpinionSectionsOpinionGuest EssaysEditorialsOp-DocsVideosLettersTopicsPoliticsWorldBusinessTechClimateHealthCultureColumnistsCharles M. BlowJamelle BouieDavid BrooksGail CollinsRoss DouthatMaureen DowdDavid FrenchThomas L. FriedmanMichelle GoldbergEzra KleinNicholas KristofPaul KrugmanCarlos LozadaTressie McMillan CottomPamela PaulLydia PolgreenBret StephensZeynep TufekciPodcastsMatter of OpinionThoughts, aloud.", 'With Michelle Cottle, Ross Douthat, Carlos Lozada and Lydia Polgreen.The Ezra Klein ShowDiscussions of ideas that matter, plus book recommendations.See all podcastsAudioAudioPodcasts and narrated articles covering news, tech, culture and more.Download the Audio app on iOS.ListenThe HeadlinesThe DailyHard ForkThe Ezra Klein ShowMatter of OpinionSerial ProductionsThe Book Review PodcastModern LoveThe Run-UpPopcastReporter ReadsThe Sunday ReadSee all audioFeaturedThe HeadlinesYour morning listen.', 'Top stories, in 5 minutes.The Kids of Rutherford CountyA series about how one county illegally jailed children.Reporter ReadsRecent articles read by the reporters behind them.NewslettersAudioOur editors share their favorite listens from the New York Times Audio app.See all newslettersAudio is included in an All Access subscription.', 'Learn more.GamesGamesWord games, logic puzzles and crosswords, including an extensive archive.PlaySpelling BeeThe Mini CrosswordWordleThe CrosswordVertexC ...

# %% [markdown]
# ### R

# %%
install.packages(c("mnormt", "psych", "SnowballC", "hunspell",
                   "broom", "tokenizers", "janeaustenr"))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘Rcpp’

# %%
install.packages("tm")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘NLP’, ‘slam’, ‘BH’

# %%
library(tokenizers)
library(tm)
library(stringr)
library(SnowballC)
library(udpipe)
library(rvest)
library(spacyr)
# Out:
# Loading required package: NLP
# Error in library(udpipe): there is no package called ‘udpipe’
# Traceback:
#
# 1. library(udpipe)

# %%
text <- tolower(readLines("text.txt", warn = FALSE))
text[0:100]
# Out:
#   [1] "first citizen:"
#   [2] "before we proceed any further, hear me speak."
#   [3] ""
#   [4] "all:"
#   [5] "speak, speak."
#   [6] ""
#   [7] "first citizen:"
#   [8] "you are all resolved rather to die than to famish?"
#   [9] ""
#  [10] "all:"
#  [11] "resolved. resolved."
#  [12] ""
#  [13] "first citizen:"
#  [14] "first, you know caius marcius is chief enemy to the people."
#  [15] ""
#  [16] "all:"
#  [17] "we know't, we know't."
#  [18] ""
#  [19] "first citizen:"
#  [20] "let us kill him, and we'll have corn at our own price."
#  [21] "is't a verdict?"
#  [22] ""
#  [23] "all:"
#  [24] "no more talking on't; let it be done: away, away!"
#  [25] ""
#  [26] "second citizen:"
#  [27] "one word, good citizens."
#  [28] ""
#  [29] "first citizen:"
#  [30] "we are accounted poor citizens, the patricians good."
#  [31] "what authority surfeits on would relieve us: if they"
#  [32] "would yield us but the superfluity, while it were"
#  [33] "wholesome, we might guess they relieved us humanely;"
#  [34] "but they think we are too dear: the leanness that"
#  [35] "afflicts us, the object of our misery, is as an"
#  [36] "inventory to particularise their abundance; our"
#  [37] "sufferance is a gain to them let us revenge this with"
#  [38] "our pikes, ere we become rakes: for the gods know i"
#  [39] "speak this in hunger for bread, not in thirst for revenge."
#  [40] ""
#  [41] "second citizen:"
#  [42] "would you proceed especially against caius marcius?"
#  [43] ""
#  [44] "all:"
#  [45] "against him first: he's a very dog to the commonalty."
#  [46] ""
#  [47] "second citizen:"
#  [48] "consider you what services he has done for his country?"
#  [49] ""
#  [50] "first citizen:"
#  [51] "very well; and could be content to give him good"
#  [52] "report fort, but that he pays himself with being proud."
#  [53] ""
#  [54] "second citizen:"
#  [55] "nay, but speak not maliciously."
#  [56] ""
#  [57] "first citizen:"
#  [58] "i say unto you, what he hath done famously, he did"
#  [59] "it to that end: though soft-conscienced men can be"
#  [60] "content to say it was for his country he did it to"
#  [61] "please his mother and to be partly proud; which he"
#  [62] "is, even till the altitude of his virtue."
#  [63] ""
#  [64] "second citizen:"
#  [65] "what he cannot help in his nature, you account a"
#  [66] "vice in him. you must in no way say he is covetous."
#  [67] ""
#  [68] "first citizen:"
#  [69] "if i must not, i need not be barren of accusations;"
#  [70] "he hath faults, with surplus, to tire in repetition."
#  [71] "what shouts are these? the other side o' the city"
#  [72] "is risen: why stay we prating here? to the capitol!"
#  [73] ""
#  [74] "all:"
#  [75] "come, come."
#  [76] ""
#  [77] "first citizen:"
#  [78] "soft! who comes here?"
#  [79] ""
#  [80] "second citizen:"
#  [81] "worthy menenius agrippa; one that hath always loved"
#  [82] "the people."
#  [83] ""
#  [84] "first citizen:"
#  [85] "he's one honest enough: would all the rest were so!"
#  [86] ""
#  [87] "menenius:"
#  [88] "what work's, my countrymen, in hand? where go you"
#  [89] "with bats and clubs? the matter? speak, i pray you."
#  [90] ""
#  [91] "first citizen:"
#  [92] "our business is not unknown to the senate; they have"
#  [93] "had inkling this fortnight what we intend to do,"
#  [94] "which now we'll show 'em in deeds. they say poor"
#  [95] "suitors have strong breaths: they shall know we"
#  [96] "have strong arms too."
#  [97] ""
#  [98] "menenius:"
#  [99] "why, masters, my good friends, mine honest neighbours,"
# [100] "will you undo yourselves?"

# %%
word_tokens <- unlist(tokenize_words(text))
word_tokens[0:100]
# Out:
#   [1] "first"      "citizen"    "before"     "we"         "proceed"
#   [6] "any"        "further"    "hear"       "me"         "speak"
#  [11] "all"        "speak"      "speak"      "first"      "citizen"
#  [16] "you"        "are"        "all"        "resolved"   "rather"
#  [21] "to"         "die"        "than"       "to"         "famish"
#  [26] "all"        "resolved"   "resolved"   "first"      "citizen"
#  [31] "first"      "you"        "know"       "caius"      "marcius"
#  [36] "is"         "chief"      "enemy"      "to"         "the"
#  [41] "people"     "all"        "we"         "know't"     "we"
#  [46] "know't"     "first"      "citizen"    "let"        "us"
#  [51] "kill"       "him"        "and"        "we'll"      "have"
#  [56] "corn"       "at"         "our"        "own"        "price"
#  [61] "is't"       "a"          "verdict"    "all"        "no"
#  [66] "more"       "talking"    "on't"       "let"        "it"
#  [71] "be"         "done"       "away"       "away"       "second"
#  [76] "citizen"    "one"        "word"       "good"       "citizens"
#  [81] "first"      "citizen"    "we"         "are"        "accounted"
#  [86] "poor"       "citizens"   "the"        "patricians" "good"
#  [91] "what"       "authority"  "surfeits"   "on"         "would"
#  [96] "relieve"    "us"         "if"         "they"       "would"

# %%
word_freq <- table(word_tokens)
word_freq[0:100]
# Out:
# word_tokens
#              3              a      abandon'd          abase          abate
#             27           3018              2              1              3
#         abated          abbey          abbot           abed         abel's
#              1              1              4              1              1
#           abet          abhor       abhorr'd       abhorred      abhorring
#              1              3              5              2              1
#         abhors       abhorson          abide         abides      abilities
#              1             16              9              3              1
#        ability      ability's         abject        abjects        abjured
#              2              1              1              1              1
#           able         aboard          abode     abodements        aboding
#             11             10              2              1              1
#     abominable       abortive         abound      abound'st          about
#              2              2              1              1             91
#          above        abraham      abraham's        abreast        abroach
#             28              6              1              1              2
#         abroad        absence         absent       absolute     absolutely
#             18             15             11              8              1
#       absolved       absolver       abstains     abstinence       abstract
#              1              1              1              2              1
#      abundance       abundant     abundantly          abuse         abused
#              3              2              1              7              8
#         abuses        abusing          abysm         accent        accents
#              3              1              1              2              2
#         accept     acceptance         access      accessary       accident
#             13              2             12              1              7
#     accidental   accidentally      accidents   acclamations accommodations
#              1              1              1              1              1
#    accompanied      accompany     accomplish   accomplish'd   accomplished
#              2              3              2              2              1
#        accompt         accord      according    accordingly        accords
#              1              1             10              1              1
#        account     account'st     accountant      accounted  accoutrements
#             17              1              1              2              1
#       accursed        accurst     accusation    accusations         accuse
#             11              1              6              3             13
#        accused        accuser       accusers        accuses       accuseth
#             10              1              2              1              1
#     accustom'd           ache          aches        achieve       achieved
#              2              2              3              5              4

# %%
stopwords <- stopwords("en")
clean_tokens <- word_tokens[!tolower(word_tokens) %in% stopwords & str_detect(word_tokens, "[A-Za-z]")]
clean_tokens[0:100]
# Out:
#   [1] "first"         "citizen"       "proceed"       "hear"
#   [5] "speak"         "speak"         "speak"         "first"
#   [9] "citizen"       "resolved"      "rather"        "die"
#  [13] "famish"        "resolved"      "resolved"      "first"
#  [17] "citizen"       "first"         "know"          "caius"
#  [21] "marcius"       "chief"         "enemy"         "people"
#  [25] "know't"        "know't"        "first"         "citizen"
#  [29] "let"           "us"            "kill"          "corn"
#  [33] "price"         "is't"          "verdict"       "talking"
#  [37] "on't"          "let"           "done"          "away"
#  [41] "away"          "second"        "citizen"       "one"
#  [45] "word"          "good"          "citizens"      "first"
#  [49] "citizen"       "accounted"     "poor"          "citizens"
#  [53] "patricians"    "good"          "authority"     "surfeits"
#  [57] "relieve"       "us"            "yield"         "us"
#  [61] "superfluity"   "wholesome"     "might"         "guess"
#  [65] "relieved"      "us"            "humanely"      "think"
#  [69] "dear"          "leanness"      "afflicts"      "us"
#  [73] "object"        "misery"        "inventory"     "particularise"
#  [77] "abundance"     "sufferance"    "gain"          "let"
#  [81] "us"            "revenge"       "pikes"         "ere"
#  [85] "become"        "rakes"         "gods"          "know"
#  [89] "speak"         "hunger"        "bread"         "thirst"
#  [93] "revenge"       "second"        "citizen"       "proceed"
#  [97] "especially"    "caius"         "marcius"       "first"

# %%
stem_tokens <- wordStem(clean_tokens)
print(stem_tokens[0:100])
# Out:
#   [1] "first"        "citizen"      "proce"        "hear"         "speak"
#   [6] "speak"        "speak"        "first"        "citizen"      "resolv"
#  [11] "rather"       "die"          "famish"       "resolv"       "resolv"
#  [16] "first"        "citizen"      "first"        "know"         "caiu"
#  [21] "marciu"       "chief"        "enemi"        "peopl"        "know't"
#  [26] "know't"       "first"        "citizen"      "let"          "u"
#  [31] "kill"         "corn"         "price"        "is't"         "verdict"
#  [36] "talk"         "on't"         "let"          "done"         "awai"
#  [41] "awai"         "second"       "citizen"      "on"           "word"
#  [46] "good"         "citizen"      "first"        "citizen"      "account"
#  [51] "poor"         "citizen"      "patrician"    "good"         "author"
#  [56] "surfeit"      "reliev"       "u"            "yield"        "u"
#  [61] "superflu"     "wholesom"     "might"        "guess"        "reliev"
#  [66] "u"            "human"        "think"        "dear"         "lean"
#  [71] "afflict"      "u"            "object"       "miseri"       "inventori"
#  [76] "particularis" "abund"        "suffer"       "gain"         "let"
#  [81] "u"            "reveng"       "pike"         "er"           "becom"
#  [86] "rake"         "god"          "know"         "speak"        "hunger"
#  [91] "bread"        "thirst"       "reveng"       "second"       "citizen"
#  [96] "proce"        "especi"       "caiu"         "marciu"       "first"

# %%
spacy_initialize(model_path = "/usr/local/lib/python3.7/dist-packages/en_core_web_sm/en_core_web_sm-3.0.0")
spacy_annotate <- spacy_parse(text)
named_entities <- spacy_entity_extract(spacy_annotate)
# Out:
# Error in spacy_initialize(model_path = "/usr/local/lib/python3.7/dist-packages/en_core_web_sm/en_core_web_sm-3.0.0"): could not find function "spacy_initialize"
# Traceback:

# %%
install.packages('xml2')
library('xml2')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("html_text")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘html_text’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
