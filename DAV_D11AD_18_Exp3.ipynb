# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshugoyal77/DAV_LAB/blob/main/DAV_D11AD_18_Exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Advertising.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
dataset.shape
# Out:
# (200, 5)

# %%
dataset.describe()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
dataset.drop(['Sales', 'Unnamed: 0'], axis=1)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = dataset['Sales']
print(x.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
print(x_train.size)
print(y_train.size)
# Out:
# 420
# 140

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept: ", mlr.intercept_)
print("Coefficients:")
list(zip(x, mlr.coef_))
# Out:
# Intercept:  2.7089490925159065
# Coefficients:
# [('TV', 0.04405928095746522),
#  ('Radio', 0.19928749689893954),
#  ('Newspaper', 0.006882452222275487)]

# %%
y_pred_mlr= mlr.predict(x_test)

# %%
mlr_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
mlr_diff.head()
# Out:
#      Actual value  Predicted value
# 95           16.9        16.565396
# 15           22.4        21.188228
# 30           21.4        21.551071
# 158           7.3        10.889238
# 128          24.7        22.202320

# %%
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr))
print('R squared: {:.2f}'.format(mlr.score(x,y)*100))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 89.39
# Mean Absolute Error: 1.5116692224549086
# Mean Square Error: 3.79679723671522
# Root Mean Square Error: 1.9485372043446387

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (140, 3)
# (140,)

# %%
sns.pairplot(data = dataset, height = 2)

# %%
print(dataset)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# independent = dataset[['TV', 'Radio']].values.reshape(-1,2)
# dependent = dataset['Sales']

# x = independent[:, 0]
# y = independent[:, 1]
# z = dependent

# fig = plt.figure(figsize = (15, 6))

# axis1 = fig.add_subplot(131, projection = '3d')
# axis2 = fig.add_subplot(132, projection = '3d')
# axis3 = fig.add_subplot(133, projection = '3d')

# axes = [axis1, axis2, axis3]

# for ax in axes:
#     ax.plot(x, y, z, color='k', zorder = 10, linestyle = 'none', marker = 'o', alpha = 0.1)
#     ax.scatter(x_range.flatten(), y_range.flatten(), predictions, facecolor = (0,0,0,0), s = 20, edgecolor = '#70b3f0')
#     ax.set_xlabel('Area', fontsize = 10, labelpad = 10)
#     ax.set_ylabel('Bedrooms', fontsize = 10, labelpad = 10)
#     ax.set_zlabel('Prices', fontsize = 10, labelpad = 10)
#     ax.locator_params(nbins = 3, axis = 'x')
#     ax.locator_params(nbins = 3, axis = 'x')

# axis1.view_init(elev=25, azim=-60)
# axis2.view_init(elev=15, azim=15)
# axis3.view_init(elev=25, azim=60)

# fig.suptitle(f'Multi-Linear Regression Model Visualization (R2 = {r2})', fontsize = 15, color = 'k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-d241c0a1566b> in <cell line: 16>()
#      16 for ax in axes:
#      17     ax.plot(x, y, z, color='k', zorder = 10, linestyle = 'none', marker = 'o', alpha = 0.1)
# ---> 18     ax.scatter(x_range.flatten(), y_range.flatten(), predictions, facecolor = (0,0,0,0), s = 20, edgecolor = '#70b3f0')
#      19     ax.set_xlabel('Area', fontsize = 10, labelpad = 10)
#      20     ax.set_ylabel('Bedrooms', fontsize = 10, labelpad = 10)
#
# NameError: name 'x_range' is not defined
